# %% [markdown]
# # Creative Nation GTR Analysis
#
# This notebook analyses Gateway to Reseaerch data for the Creative Nation report.
#
# We start with a list of projects classified by Discipline (based on the Arloesiadur analysis) and we classify those projects into different categories based on the nature of the organisations involved:
#
# `````
#                 Creative
#                 organisation
#                 Y     N
# =============================
# Creative    Y  CI    CE
# discipline  N  EK    OTHER
# =============================
#
# ```
#
# * ```CI```: A creative organisation engaging with a creative discipline.
# * ```CE```: A non-creative organisation engaging with a creative discipline.
# * ```EK```: A creative organisation engaging with a non-creative discipline.
# * ```OTHER```: A non-creative organisation engaging with a non-creative project.
#
# **Definitions**
#
# We define **creative organisations** based on DCMS SIC codes
#
# How do we deal with creative non-commercial organisations and creative stakeholders e.g. BBC, Arts Council, Design Council etc.? Use members of the Creative Industries Council or Federation
#
# We define **creative disciplines** based on their creative intensity (the relative importance of creative businesses in the discipline).
#
# **Activities**
#
# 1. Load GtR data
#    * Are we doing anything with Innovate UK and other data sources?
# 2. Query org names vs Companies House
# 3. Identify creative non-commercial orgs
# 4. Define creative disciplines
# 5. Classify projects
# 6. Consider options for SNA.

# %% [markdown]
# # 1. Preamble

# %%
#Imports

% matplotlib inline

#Use this script to format some of the code as markdown
from IPython.display import Markdown, display
def printmd(string):
    display(Markdown(string))

#Utilities
import os
import urllib3
import requests
import zipfile
import json
import pickle
import datetime
import sys
import http.client, urllib.request, urllib.parse, urllib.error, base64
import re


#Data 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from itertools import combinations

import http.client, urllib.request, urllib.parse, urllib.error, base64

#Analytical
import networkx as nx
import community

#Otheer
import ratelim
from bs4 import BeautifulSoup
import chwrapper


#Paths
top = os.path.dirname(os.getcwd())

#External data (to download the GRID database)
ext_data = os.path.join(top,'data/external')

#Interim data (to place seed etc)
int_data = os.path.join(top,'data/interim')

#Figures
fig_path = os.path.join(top,'reports/figures')


#Get date for saving files
today = datetime.datetime.today()

today_str = "_".join([str(x) for x in [today.day,today.month,today.year]])

#Increase number of recursions to save a pickle file later
sys.setrecursionlimit(10000)

#Token
#Load token
with open(top+'/keys.json','r') as infile:
    tokens = json.load(infile)
ch_token = tokens['ch']

# %%
#Write the class to do this

class GTR_org():
    '''
    We use this class to process a set of companies from Gateway to Research.
    This involves:
        Querying CH with the company name
        Disambiguate results with the GTR company postcode
        Matching the results with the CH datadump using CH number and obtaining the SIC code
        Classifying companies into CE sectors based on their SIC code
    
    '''
    
    def __init__(self,company_name,company_post_code,company_id,token=ch_token):
        '''
        Initialise with the access token and the company name 
        '''
        #Initialise the search client
        self.token = token
    
        #Get the company name (from GTR)
        self.name = company_name
        
        #Get the company postcode (from GTR)
        self.post_code = company_post_code
        
        #Get the company ID (from GTR)
        self.id = company_id
    
    @ratelim.patient(550,time_interval=300)
    def query_ch(self):
        '''
        Query CH using the ch wrapper
        '''
        
        #Initialise the search client
        search_client = chwrapper.Search(self.token)
        
        #Search company
        search_results = search_client.search_companies(self.name)
        
        #We either get results of a failure
        
        #If we get a result
        if search_results.status_code == 200:
            self.results = search_results
            self.json = search_results.json()
            self.success = True
        
        else:
            self.results= search_results
            self.json = {'failed_query: {error}'.format(error=search_results.status_code)}
            self.success = False    
    
    def get_best_result(self):
        '''
        Extract results and get postcode matches
        
        '''
        #Only does this if the query was successful
        #This is quite long. Probably shoud create some functions and take out of here
        
        if self.success == True:
            
            #Extract all results
            items = self.json['items']
            
            #If there are any results!
            if len(items)>0:
            
                
                all_results_pc = [[x['address']['postal_code'] 
                                if 'postal_code' in x['address'].keys() else 'no_postal_code',x] for x in items if
                                 x['address']!=None]
                
                #Only returns those results with a match on postcodes
                postcode_matches = [x[1] for x in all_results_pc if x[0]==self.post_code]
                
                #How many matches on postcode do we get?
                self.number_matches = len(postcode_matches)
                
                if len(postcode_matches)>0:
                    #For now, focus on the top result returned by CH <- check_this
                    self.best_match = postcode_matches[0]

                    self.best_ch_number = postcode_matches[0]['company_number']
                    
                else:
                    self.best_match = 'no_matches'
                    self.best_ch_number = 'no_matches'
        
            else:
                self.best_match = 'no_addresses'
                self.best_ch_number = 'no_addresses'
        
        else:
            self.best_match = 'no_data'
            self.best_ch_number = 'no_data'
            
                
    
    def get_ch_data(self,ch,creative_lookup):
        
        '''
        Extract metadata from ch dataset
        
        '''
        
        #If the system hasn't failed, match vs. ch
        
        if self.best_ch_number not in ['no_data','no_matches','no_addresses']:
            
            #Fortunately, the company numbers are strings so we can match without too much hassle
            company_match = ch.loc[ch.CompanyNumber==self.best_ch_number,:]
            self.company_match = company_match
            
            if len(company_match)==0:
                company_match = 'no_ch_metadata'
                self.sic_4 = 'no_ch_metadata'
                self.is_creative = 'no_ch_metadata'
                self.creative_sector = 'no_ch_metadata'
            
            else:
                #self.ch_database_match = company_match
                
                #Extract SIC code
                sic_code = list(company_match['SICCode.SicText_1'])[0]
                
                #Perhaps pre-process this in the ch data above
                
                #There are missing values in the SIC codes
                
                if sic_code != 'None Supplied':
                    
                    #If it is not missing, separate the sector code from the text description
                    sic_number = sic_code.split(" -")[0]
                    
                    #Some of them are 4 digits and some are 5
                    if len(sic_number)<5:
                        self.sic_4 = sic_number
                    else:
                        self.sic_5 = sic_number
                        self.sic_4 = sic_number[:-1]
                        
                    #Now match with CIs:
                    if self.sic_4 in [str(x) for x in ce_lookup.keys()]:
                        self.is_creative = True
                        self.creative_sector = creative_lookup[self.sic_4]
                    else:
                        self.is_creative = False
                        self.creative_sector = 'non_creative'
                
                else:
                    self.sic_4 = 'no_sic'
                    self.is_creative = 'no_sic'
                    self.creative_sector = 'no_sic'
        else:
            self.company_match = self.best_match
            self.sic_4 = self.best_match
            self.is_creative = self.best_match
            self.creative_sector = self.best_match
                    
    def process_all(self):
        '''
        Process all the data with the 3 methods above
        
        '''
        
        self.query_ch()
        self.get_best_result()
        self.get_ch_data()

# %% [markdown]
# ## 1. Load project data

# %%
#Load Gateway to research projects and organisations
projects = pd.read_csv(ext_data+'/gtr_projects.csv')
orgs = pd.read_csv(ext_data+'/gtr_organisations.csv')

#Addresses
with open(ext_data+'/org_geo.p','rb') as infile:
    org_lat_lng_dict = pickle.load(infile)

# %%
#Load the CSV data

cols_to_keep = ['CompanyName', ' CompanyNumber','RegAddress.PostCode','IncorporationDate',
                'SICCode.SicText_1', 'SICCode.SicText_2', 'SICCode.SicText_3','SICCode.SicText_4',
               'CompanyStatus','CountryOfOrigin']

#Read the data
ch_df = pd.read_csv(ext_data+'/BasicCompanyDataAsOneFile-2017-07-01.csv',usecols=cols_to_keep)
ch_df.columns = [x.strip() for x in ch_df.columns]

# %%
#Read DCMS codes
ce_codes = pd.read_csv(ext_data+'/ce_codes.csv')

ce_lookup = {str(x):y for x,y,z in zip(ce_codes.code,ce_codes.label2,ce_codes.type) if z=='SIC'}

# %% [markdown]
# ## 2. Load Companies House matched data

# %% [markdown]
# No postcode examples are outside the UK, no address are a mix of orgs outside the UK and departments and organisations with little data.

# %%
#Load the data from the queries we ran
with open(int_data+'/gtr_query_results.p','rb') as infile:
    gtr_processing_results = pickle.load(infile)

# %% [markdown]
# ## 3. Load Grid matched data

# %%
#Load the extract_charity data
#We will use the fuzzywuzzy fuzzy matching package
from fuzzywuzzy import fuzz
from fuzzywuzzy import process


def extract_country_institutions(grid_file,country_list):
    '''
    Extracts contact details for the institutions in a country
    country is a list (we can extract information from more than one country)
    
    
    '''
    
    #List of institutes
    institute_list = grid_file['institutes']
    
    #Some institutes have no address - they are 'redirected'.
    #We don't need their information
    
    institute_w_address = [x for x in grid['institutes'] if 'addresses' in x.keys()]
    
    #Get institutes in country
    institutes_in_country = [x for x in institute_w_address if x['addresses'][0]['country_code'] in country_list]
    
    #Return institutes
    return(institutes_in_country)

def flatten(my_list):
    '''
    Goes through elements in a list and if they are not empty, it extracts the first value. 
    Otherwise it turns values into nans.
    
    '''
    
    flat = [x[0] if len(x)>0 else np.nan for x in my_list]
    return(flat)
# Out:
# /usr/local/lib/python3.5/site-packages/fuzzywuzzy/fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
with open(ext_data+'/grid.json', 'r') as infile:
    grid = json.load(infile)

#iso code for emirates = AE
uk_institutes = extract_country_institutions(grid,['GB'])

#Get information 
uk_res_df = pd.DataFrame([[x['name'],x['addresses'][0]['city'],x['addresses'][0]['lng'],
                           x['addresses'][0]['lat'],
                          x['links'],x['wikipedia_url'],x['types']] for x in uk_institutes],
                       columns=['name','city','lon','lat','url','wikipedia','type'])

#Flatten (ie. extract elements from lists)
uk_res_df['url'] = flatten(uk_res_df['url'])
uk_res_df['type'] = flatten(uk_res_df['type'])

#Here are the UK research institutions
uk_research_institutions = uk_res_df.loc[uk_res_df.type !='Company',:]

#Lower case and stripped name
uk_research_institutions.loc[:,'name'] = [x.lower().strip() for x in uk_research_institutions['name']]
# Out:
# /usr/local/lib/python3.5/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
with open(int_data+'/grid_matches.p','rb') as infile:
    grid_matches = pickle.load(infile)

# %%
np.sum([x[2]!='no_good_match' for x in grid_matches])
#We got 639 matches here. Let's see what they are.

grid_matches_df = pd.DataFrame([[x[0],x[1],x[2][0],x[2][1]] for x in grid_matches if x[2]!='no_good_match'],
                              columns=['org_id','gtr_name','grid_name','score'])


grid_matches_df.iloc[:,:50]
#Assumption - these ones will have a massive presence in GTR. Let's see.
# Out:
#                                    org_id  \
# 0    AEBFFA9B-9B1E-4235-96E2-ACB761119425
# 1    9D2232B9-DC18-4507-96F6-63DAE75B0284
# 2    C9E3BB74-B3E7-4454-9C35-8EB1373856B7
# 3    58451366-6877-4B7D-B2D4-8D0416BA6DFD
# 4    5BB4F8BF-B4E0-4EAF-9AF5-885E19D64850
# 5    289B3363-B06A-4E83-9F57-80E81DCB0DA2
# 6    9152582B-272B-4BE3-8223-A92E94DF0D75
# 7    440BEB68-030A-41A9-924E-02DCF0DD71D4
# 8    09B4D85F-B21E-4FB5-A591-07DCB5E231B0
# 9    7C771F1D-4232-4D26-BB06-09A91AE633E5
# 10   86BA0D2C-1895-41C5-B18C-092178DFFB3E
# 11   55DE595B-C980-4097-8586-11A4C7ACC94C
# 12   6D020EDE-0258-4435-9B2C-0BFB8DB31F84
# 13   961756BF-E31F-4A13-836F-0A09BA02385C
# 14   1BB66625-E529-4E8D-B1F6-0D500FA18BF5
# 15   83FEDA17-7226-44E8-B3DC-7A8D598B0CA8
# 16   A6A04C19-3A45-42C9-8E22-0C30EC08C456
# 17   311CF7DB-5FCA-4763-9070-685B4CFF608B
# 18   E7910513-EA16-41B2-A0C0-7F49C936A4BF
# 19   D4147631-112B-45C7-8654-88569CA5A5B8
# 20   0C59D7DD-0A3A-4639-BB00-B52604E6B91C
# 21   FE24BCA5-13DD-4976-B7C1-A1D060CB7A8E
# 22   9C714F41-870B-4CD5-BDFC-8FA613492C47
# 23   1025786D-FA5D-4EEF-AC51-B580119D17B8
# 24   772A1E12-7175-46C0-B665-CE27930D15A8
# 25   91E49C8E-E497-4CD8-8B7C-7284109BA92B
# 26   D93E17F7-8917-4766-B866-C9A157FE8535
# 27   8CC2E3CE-75FA-461F-A3B0-860D294D060B
# 28   91FEA6C9-D621-4F85-8272-EEE8A3CA4996
# 29   64BC5E73-972F-41E1-A12C-D97DC9BDFB93
# ..                                    ...
# 609  AC129B08-22EA-4B9B-88DC-1F756C93D601
# 610  66F9AE66-B747-4A8B-AD95-32E152E0BC20
# 611  268E2A2F-0437-4978-98EC-D90F1E1DA550
# 612  FD5C64CF-6841-4A68-9D9C-FD87A4EE56A3
# 613  E594FDB4-DD6F-441F-90D6-C423A2916446
# 614  1EA85341-3669-47D5-A587-D373DFB2527F
# 615  916F1BA2-74FF-4AE3-8F0B-F045B6DC5660
# 616  EDAC6956-BD23-4B16-A231-C6FEFA5F4965
# 617  7C6A477A-29DD-4C7C-A599-03CEFBDBDB3F
# 618  A0C5B84A-07CC-4BEB-B8D5-12EC97B8001D
# 619  96C38D92-C4B6-4E57-B1FD-26B2A7886B4F
# 620  8051A6AF-3221-479F-8126-55CC7773479F
# 621  1A3C4B4D-A492-43D4-BD25-729BD718D1E9
# 622  098DBCCE-4144-4026-9B7E-6A5EE41CF563
# 623  428D1385-83F6-4592-BD2D-3829D72ABEC1
# 624  0FD01CC2-BEC0-446C-B6B3-492C7AEEBAD6
# 625  1AF5F6BE-7C00-4B82-9E89-38545CE86CB4
# 626  2BA3C484-FA19-4E5D-BBB7-2FCFAD740307
# 627  216FC45A-E5D3-4990-A025-3D44AF570640
# 628  B31F43C2-2005-4204-B56A-3BF9DC16485D
# 629  DE83E776-ABF4-4EE3-AEAC-5F888ADEBD56
# 630  DBB1D123-EB50-4431-AA1A-7135747CB9B5
# 631  37DE1B14-06DD-4E06-AAC5-56F5BBED7FFF
# 632  D269FD2E-8EBB-4D54-9C4E-3B7603EC2407
# 633  ABBC8A7F-80FB-4544-A424-39B80DAC681E
# 634  5F3D46B0-7A82-4C7B-8F15-45BEC376DACC
# 635  703E38C8-1C6E-4EE3-9AFD-6CCA38A6F956
# 636  DF6FF94A-1B24-46BE-8108-E8DFE8922EAD
# 637  A8D73CC8-4FB1-44CB-BD2F-CCB476979C69
# 638  2DB7ED73-8E89-457A-A395-FAC12F929C1A
#
#                                               gtr_name  \
# 0                             South West College Omagh
# 1             Royal Pharmaceutical Society of Great Br
# 2           Association for the Conservation of Energy
# 3                    The Royal Institute of Navigation
# 4                            University of Strathclyde
# 5    University Hospital Southampton NHS Foundation...
# 6    Department of Agriculture & Rural Development ...
# 7                                 The Ideas Foundation
# 8               Scottish Universities Physics Alliance
# 9                                    The Arts Catalyst
# 10              National Institute for Health Research
# 11                      Maritime and Coastguard Agency
# 12                              Trinity College London
# 13                                University of Exeter
# 14                                Epilepsy Research UK
# 15                        Forestry Commission Scotland
# 16                                 Kent County Council
# 17                                 Exeter City Council
# 18                                 University of Wales
# 19                         Devon Partnership NHS Trust
# 20                     Economic Policy Research Centre
# 21              North East London NHS Foundation Trust
# 22                                  Transport Scotland
# 23                  The Orders of St John's Care Trust
# 24                    Liverpool John Moores University
# 25                               Surrey County Council
# 26               British Cattle Veterinary Association
# 27                            West Cumberland Hospital
# 28                           UK Energy Research Centre
# 29                        MRC Clinical Sciences Centre
# ..                                                 ...
# 609                 Offshore Renewable Energy Catapult
# 610                                 Scottish Enterpise
# 611                                  Collections Trust
# 612                  The British Psychological Society
# 613                 Manchester Metropolitan University
# 614                       Hertfordshire County Council
# 615                                         Royal Navy
# 616                             Pain Relief Foundation
# 617                             Action on Hearing Loss
# 618             Stockport Metropolitan Borough Council
# 619                           Hampshire County Council
# 620                             National Welsh College
# 621                        University of Wolverhampton
# 622             Northampton General Hospital NHS Trust
# 623             Department for Regional Development NI
# 624                       Southampton General Hospital
# 625                  Pennine Acute Hospitals NHS Trust
# 626                                    The Home Office
# 627                                 Holy Cross College
# 628                                              Nesta
# 629                                     Boston College
# 630                                   Concrete Society
# 631                                MRC Toxicology Unit
# 632                   Golden Jubilee National Hospital
# 633                           Department for Education
# 634               Redcar and Cleveland Borough Council
# 635                    Dr Williams's Trust and Library
# 636                   Communities and Local Government
# 637                         Fraunhofer UK Research Ltd
# 638                            University of Edinburgh
#
#                                              grid_name  score
# 0                                   south west college     95
# 1                         royal pharmaceutical society     95
# 2           association for the conservation of energy    100
# 3                        royal institute of navigation     95
# 4                            university of strathclyde    100
# 5    university hospital southampton nhs foundation...    100
# 6      department of agriculture and rural development     91
# 7                                     ideas foundation     95
# 8               scottish universities physics alliance    100
# 9                                        arts catalyst     95
# 10              national institute for health research    100
# 11                      maritime and coastguard agency    100
# 12                              trinity college london    100
# 13                                university of exeter    100
# 14                                epilepsy research uk    100
# 15                        forestry commission scotland    100
# 16                                 kent county council    100
# 17                                 exeter city council    100
# 18                                 university of wales    100
# 19                         devon partnership nhs trust    100
# 20                 centre for economic policy research     95
# 21              north east london nhs foundation trust    100
# 22                                  transport scotland    100
# 23                        orders of st john care trust     95
# 24                    liverpool john moores university    100
# 25                               surrey county council    100
# 26                      british veterinary association     95
# 27                            west cumberland hospital    100
# 28                           uk energy research centre    100
# 29                        mrc clinical sciences centre    100
# ..                                                 ...    ...
# 609                 offshore renewable energy catapult    100
# 610                                scottish enterprise     97
# 611                                  collections trust    100
# 612                      british psychological society     95
# 613                 manchester metropolitan university    100
# 614                       hertfordshire county council    100
# 615                                         royal navy    100
# 616                             pain relief foundation    100
# 617                             action on hearing loss    100
# 618             stockport metropolitan borough council    100
# 619                           hampshire county council    100
# 620                             welsh national college     95
# 621                        university of wolverhampton    100
# 622                       northampton general hospital     95
# 623                department for regional development     96
# 624                       southampton general hospital    100
# 625                  pennine acute hospitals nhs trust    100
# 626                                        home office     95
# 627                                 holy cross college    100
# 628                                              nesta    100
# 629                                     bolton college     93
# 630                                   concrete society    100
# 631                                mrc toxicology unit    100
# 632                   golden jubilee national hospital    100
# 633                           department for education    100
# 634               redcar and cleveland borough council    100
# 635                              dr williams's library     95
# 636    department for communities and local government     95
# 637                             fraunhofer uk research     95
# 638                            university of edinburgh    100
#
# [639 rows x 4 columns]

# %%
#35% of all projects
np.sum([x in set(grid_matches_df['org_id']) for x in projects['org_id_short']])/len(projects)
# Out:
# 0.34882462498741568

# %%
#We can combine this with the grid_data to determine the type of organisation
#Later, we can remove these from the GTR data.
grid_matches_meta_df = pd.merge(grid_matches_df,uk_research_institutions,left_on='grid_name',right_on='name')

#These are the types of organisations in the data
grid_matches_meta_df['type'].value_counts()
# Out:
# Healthcare    157
# Government    154
# Nonprofit     106
# Education      85
# Other          64
# Facility       52
# Archive        26
# Name: type, dtype: int64

# %% [markdown]
# ## 3. Combine sources
#
# Stages
#
# * Create DF with SIC codes
# * Load SIC - sector lookup and rearrange topics
# * Relabel education as academic
# * Combine with university data and relabel fields
# * Combine with geo data
# * Load projects (with topics)
# * Think strategy for analysis

# %%
#Initial data load: 
#Segments
industry_segments = pd.read_csv(ext_data+'/industry_cluster_lookup_feb_2017.csv',dtype='str')

industry_segments['sic_4'] = [str(x) if len(str(x))==4 else '0'+str(x) for x in industry_segments['sic_4']]


#Projects (labelled)
projects_comms = pd.read_csv(ext_data+'/3_08_2017_projects_topic_communities.csv')

# %%
#Create dict lookup
sic_industry_lookup = {x:y for x,y in zip(industry_segments['sic_4'],industry_segments['cluster'])}

# %%
#Extract data from the gtr_processing results file
#These are the CH data 
ch_matched = pd.concat([pd.DataFrame(x,index=['id','name','ch_metadata','sic','type']).T for x in gtr_processing_results])

# %%
#The dates are quite gnarly because they are in different formats. I had to sort them with a loop.
ch_dates = []

for num,x in enumerate(gtr_processing_results):
    if type(x[2]!=str):
        try:
            ch_dates.append(x[2]['IncorporationDate'].iloc[0])
        except:
            ch_dates.append(np.nan)
    else:
        ch_dates.append(np.nan)

# %%
ch_matched['inc_date'] = ch_dates

# %%
#Data with matched SICs
ch_matched_sics = ch_matched.loc[[x not in ['no_matches','no_addresses','no_ch_metadata','no_sic'] for x in 
                                 ch_matched.sic],:].reset_index(drop=True)


ch_matched_sics.drop(['ch_metadata','type'],axis=1,inplace=True)

# %%
#Now we convert them to clusters
ch_matched_sics['industry'] = [sic_industry_lookup[x] if x in sic_industry_lookup.keys() else 'no_cluster' for x in ch_matched_sics['sic']]

ch_matched_sics['domain'] = ['industry' if 'education' not in x else 'education' for x in ch_matched_sics['industry']]

# %%
#Makes sense. We will turn the 'services education post primary' into 'education'
ch_matched_sics['industry'].value_counts()[:20]
# Out:
# services_computing                 1079
# services_r_&_d                      898
# services_creative                   598
# no_cluster                          490
# services_administrative             453
# manufacture_machinery_tools         382
# manufacture_electronics             378
# services_utilities                  370
# services_professional               337
# services_financial_legal            329
# manufacture_furniture               326
# services_kibs                       261
# manufacture_food                    243
# services_wholesale                  216
# services_education_post_primary     206
# services_recreation                 188
# manufacture_chemical                163
# manufacture_electrical              159
# construction_construction           149
# services_entertainment              149
# Name: industry, dtype: int64

# %%
#Now we want to combine grid here

grid_match = grid_matches_meta_df[['org_id','gtr_name','type']]
grid_match.rename(columns={'org_id':'id','gtr_name':'name','type':'domain'},inplace=True)

grid_match['domain'] = [x.lower() if type(x)==str else np.nan for x in grid_match['domain']]


org_sectors = pd.concat([ch_matched_sics,grid_match])
# Out:
# /usr/local/lib/python3.5/site-packages/pandas/core/frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # Analysis
#
# **Actions**
#
# 1. Org with org metadata and geography
# 2. Create inputs for the class: edge list with distances between nodes.
# 3. Class with relevant methods:
#  * get_topic_participants(topic)
#  * get_industry_topics(industry or domain)
#  * get_distance_matrix (topic)
#  * Get interdisciplinary activity
#  * Get interdisciplinary distance

# %%
#First thing. lat lon

import geopy
import time

geolocator = geopy.Nominatim()

# %%
with open(ext_data+'/org_lat_lng_dict.p','rb') as infile:
    org_lat_long = pickle.load(infile)

#Create DF
org_lat_long_df = pd.DataFrame(org_lat_long).T
org_lat_long_df.index = [x.lower() for x in org_lat_long_df.index]

# %%
#Join. NB we have lost quite a few observations here. Unclear why. Come back to this
org_geo = org_sectors.set_index('name').join(org_lat_long_df)

# %%
#Org to geo need to be geocoded too.
org_to_geo = org_geo.loc[org_geo.lon.isnull(),:]

# %%
orgs_with_address = orgs.loc[[len(json.loads(x)['address'])>0 for x in orgs['addresses']],:]

orgs_with_address['addresses'] = [json.loads(x) for x in orgs_with_address['addresses']]
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
#Therse are organisations that need to be geocoded

orgs_with_address_selected = orgs_with_address.loc[[x.lower() in org_to_geo.index for x in 
                                                    orgs_with_address.name],:].reset_index(drop=True)

# %%
#Clas

def osm_series_converter(osm_json,address_keys=['postcode', 'suburb', 'city', 'university', 'county', 'country_code', 'state', 'road', 'country']):
    '''
    Takes an osm json object and returns a pandas series.
    NB it also takes a list of address keys to create an empty series in case we have missing addresses
    '''
    
    #Extract address
    try:
        series_metadata = osm_json['address']
    except:
        series_metadata = {x:np.nan for x in address_keys}
    
    for x in ['importance','lon','lat','type']:
        try:
            series_metadata[x] = osm_json[x]
        except:
            series_metadata[x] = np.nan
            
    series_out = pd.Series(series_metadata)
    return(series_out)
    

class OsmQuerier():
    '''
    Class to query the Open Street Map Nomatim API
    
    '''
    
    def __init__(self,
                 base_url="http://nominatim.openstreetmap.org/search?q={place}&format=json&addressdetails=1"):
        '''
        Reads the base url.
        
        '''
    
        self.base_url = base_url
        
    @ratelim.patient(max_calls=60,time_interval=60)
    def query_osm(self,place):
        '''
        Takes a string, queries the OSM API and returns the top result with key fields as a Df 
        
        '''
        
        #Format the string (lowercase, replace spaces with +)
        query_string = "+".join(place.lower().split(" "))
        
        self.query_string = query_string
        #Format the base_url
        url = self.base_url.format(place=query_string)
        
        #Run query
        try:
            #Run query
            response = requests.get(url)
            json_object = response.json()
            
            self.json = json_object
            
        #If we obtain an exception like this, return an error
        except requests.exceptions.RequestException as e:
            return("Error:{}".format(e))
            self.json = []
    
    def best_match_data(self):
        '''
        Loops over the json object (if there is anything to loop over) and creates a datafrae with results.
        It then returns the best result
        
        '''
        
        if len(self.json)<1:
            output = osm_series_converter(self.json)
            output['n_results'] = len(self.json)
            output['query'] = self.query_string
            self.parsed_output = output
            self.best_output = output
        
        else:
            output = [osm_series_converter(x) for x in self.json]
            
            concat_output= pd.concat(output,axis=1).T.reset_index(drop=False)
            concat_output['n_results'] = len(self.json)
            concat_output['query'] = self.query_string
            
            self.parsed_output = concat_output
            self.best_output = concat_output.sort_values('importance',ascending=False).iloc[0,:]
        
        
        #out = [osm_series_converter(x) for x in ]
        
    def run_pipeline(self,place,num):
        '''
        Runs the things above
        '''
        
        #Counter
        if num %100 == 0:
            print(num)
        
        self.query_osm(place)
        self.best_match_data()
        
        return(self)

# %%
orgs_with_address_selected['address_to_geocode'] = [" ".join([
    val.lower() for key,val in x[
        'address'][0].items() if 'line' in key])+" "+ x[
    'address'][0]['postCode'].lower() if 'postCode' in x['address'][0].keys() else "" for x in 
                                                    orgs_with_address_selected['addresses']]

# %%
orgs_with_address_selected['address_to_geocode'] = [re.sub(
    '\n','',x) for x in orgs_with_address_selected['address_to_geocode']]

# %%
addresses_to_geocode = [re.sub('\n','',x) for x in orgs_with_address_selected.address_to_geocode]

addresses_geocoded = []

for num,x in enumerate(addresses_to_geocode):
    
    try:
        output= OsmQuerier().run_pipeline(x,num)
        addresses_geocoded.append(output)
        
    except:
        addresses_geocoded.append('error')
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600

# %%
#8 errors
error_indices = [num for num,x in enumerate(addresses_geocoded) if x=='error']
error_indices
# Out:
# [1782, 1786, 1787, 1788, 2324, 2400, 2477, 2484, 2489, 3547]

# %%
for x in error_indices:
    print(addresses_to_geocode[x])
# Out:
# bristol and bath science parkemersons green bs16 7fr
# 21 hawthornvale bill scott sculpture centre eh6 4jt
# sruc edinburgh campus king's buildings , west mains road eh9 3jg
# lansdowne house , berkeley square w1j 6er
# 23 king street , suite #280 cb1 1ah
# net park , thomas wright way ts21 3fd
# the cam centre , wilbury way sg4 0tw
# oddfellows house , 19 newport road cf24 0aa
# 5 tenterfield closegreenfieldoldham ol3 7fp
# future business centre , kings hedges road cb4 2hy

# %%
#Outputs
#Extract addresses
addresses_geocoded_df = pd.concat([x.best_output if x!='error' else pd.DataFrame({'error':True},index=[0]).T for x in addresses_geocoded],
                               axis=1).T[['country_code','country','lat','lon','n_results','query']]

#addresses_geocoded[0].best_output
addresses_geocoded_df.to_csv(int_data+'/{today}_gtr_org_addresses_geocoded.csv'.format(today=today_str))

# %%
#This df contains all the geocoded addresses
orgs_geocoded_df = pd.concat([orgs_with_address_selected.reset_index(drop=True),
                              addresses_geocoded_df.reset_index(drop=True)],axis=1)

# %%
#We have managed to geocode another 1345
np.sum(orgs_geocoded_df['lat'].isnull()==False)
# Out:
# 1348

# %%
#Combine all orgs including those that we geocoded and those that we didn't.

#Processing the organisations that originally had geocoded data
org_geo_to_merge = org_geo.dropna(axis=0,subset=['lat']).reset_index(drop=False).set_index('id')
org_geo_to_merge.rename(columns={'index':'name'},inplace=True)

#Processing the organisations that *now* have geocoded data
org_new_geo_to_merge = pd.merge(org_to_geo.reset_index(drop=False)[
    ['id','domain','index','inc_date','industry','sic']],
                                orgs_geocoded_df,
                                    left_on='id',right_on='id').reset_index(
    drop=False)[['id','name', 'domain', 'inc_date', 'industry', 'sic', 'lat', 'lon']].set_index('id')

org_new_geo_to_merge.rename(columns={'index':'name'},inplace=True)


final_org_set = pd.concat([org_geo_to_merge,org_new_geo_to_merge])    
final_org_set.rename(columns={'index':'name'},inplace=True)

final_org_set = final_org_set.dropna(subset=['lat'],axis=0)

# %%
grid_matches_meta_df['domain'] = grid_matches_meta_df['type']

grid_matches_not_geocoded = grid_matches_meta_df.loc[[x not in final_org_set.index for x in
                                                     grid_matches_meta_df['org_id']],
                                                    ['org_id','gtr_name','lon','lat','domain']]

grid_matches_not_geocoded.rename(columns={'gtr_name':'name'})

final_org_set_2 = pd.concat([final_org_set,grid_matches_not_geocoded.set_index('org_id')])

final_org_set_2 = final_org_set_2.dropna(subset=['lat'],axis=0)

# %%
#Calculate distances
#Create a network where every edge is a pair of organisations (we keep the id for )

projects_by_id = projects.groupby('project_id')['org_id_short'].apply(lambda x: list(x)).reset_index(drop=False)

#Create edges
edge_list = pd.concat([pd.concat(
    [pd.DataFrame(list(combinations(set(x),2)),columns=['e1','e2']),
     pd.DataFrame({'pid':[y]*len(list(combinations(set(x),2)))})],axis=1) for x,y in
                       zip(projects_by_id['org_id_short'],
                          projects_by_id['project_id'])])

# %%
#Now we want to, for each pair of obs, obtain the distance.

final_org_coords = {x:(lat,lon) for x,lat,lon in zip(final_org_set_2.index,
                                                    final_org_set_2.lat,
                                                    final_org_set_2.lon)}

# %%
#Focus on 
edge_list_with_coords = edge_list.iloc[[x in final_org_coords.keys() for x in edge_list['e1']],:]
edge_list_with_coords = edge_list_with_coords.iloc[[x in final_org_coords.keys() for x in edge_list_with_coords['e2']],:]

# %%
from geopy.distance import vincenty

# %%
# %%time
#Extract distances
edge_list_with_coords['distances'] = [vincenty(final_org_coords[x],final_org_coords[y]).miles 
                                      for x,y in zip(edge_list_with_coords['e1'],
                                                     edge_list_with_coords['e2'])]
# Out:
# CPU times: user 2.46 s, sys: 12.6 ms, total: 2.48 s
# Wall time: 2.48 s

# %%
edge_list_with_coords.distances.describe()
# Out:
# count    55540.000000
# mean       116.058306
# std         96.774554
# min          0.000000
# 25%         45.381371
# 50%         96.065011
# 75%        163.145014
# max        612.517563
# Name: distances, dtype: float64

# %%
#Project allocations to topics
project_allocs = pd.concat([projects['project_id'],
                            projects.loc[:,[x for x in projects.columns if 'tc_' in x]].apply(lambda x: x.idxmax(),
                                                                                            axis=1)],axis=1)

#Merge with the edge list

edge_list_with_coords = pd.merge(edge_list_with_coords,project_allocs,
                                left_on='pid',right_on='project_id')

edge_list_with_coords.rename(columns={0:'field'},inplace=True)

# %%
#Mean/median distances
edge_list_with_coords.groupby('field')['distances'].aggregate(['mean','median']).sort_values('median')
# Out:
#                                            mean      median
# field
# tc_architecture_spatial               45.968819    4.104008
# tc_military_history                   33.506631    4.752904
# tc_health_social_issues               33.695155    4.885052
# tc_philosophy                         25.819364    6.028743
# tc_classic_religious_history          48.148793   12.886244
# tc_visual                             66.007181   15.489025
# tc_migration_colonial_history         46.789327   34.049160
# tc_linguistics                        52.411309   44.595181
# tc_computer_vision                    58.792582   48.203597
# tc_gender_sexuality                   96.169856   50.085592
# tc_disease_infection_health           85.936315   56.917646
# tc_statistics_data_analysis           68.389187   59.093685
# tc_evidence_for_policy                77.344729   60.287487
# tc_cyber_security                     73.607603   60.321982
# tc_networks                           90.389366   60.699550
# tc_literature                        113.007890   67.357597
# tc_medieval_modern_history            96.646017   68.369710
# tc_cellular_biology_cancer            97.010972   74.809582
# tc_cognition_&_audio                 109.280711   78.287584
# tc_development_studies                97.590805   78.528605
# tc_media_performance                  96.391547   78.970757
# tc_transport_communications           90.514921   79.973933
# tc_computer_science                  120.346297   81.452260
# tc_robotics_cybernetics               96.692532   83.728538
# tc_systems_infrastructure             97.309084   83.734175
# tc_archaeology                        99.267440   84.084669
# tc_criminology_violence               76.591414   85.333614
# tc_astrophysics                      111.729658   87.366057
# tc_education                         104.160057   87.425072
# tc_electronics_transistors           128.361475   88.302533
# ...                                         ...         ...
# tc_social_history                    122.695690  107.269006
# tc_ageing                            128.949842  107.381559
# tc_experiments                       129.537153  107.471492
# tc_modelling_measurement             120.517277  107.999838
# tc_bones_muscles                     143.289688  112.896365
# tc_particle_physics                  134.633297  112.974548
# tc_industrial_application            133.348796  117.210225
# tc_health_interventions_policy       134.988308  119.314686
# tc_psychology                        124.723735  119.457179
# tc_ecosystems                        141.217924  121.229070
# tc_environmental_policy              136.153064  121.936252
# tc_obesity_metabolism                143.752473  122.189998
# tc_public_engagement_infrastructure  139.856502  125.321883
# tc_chemistry_biochemistry            141.395981  126.014646
# tc_minerals_fuels                    118.262528  126.380149
# tc_cosmology                         138.038359  127.155288
# tc_modelling_&_sensors               130.913467  127.316376
# tc_climate_science                   146.195683  127.316376
# tc_energy_environmental              140.266610  129.149183
# tc_respiratory_system                135.485995  129.816834
# tc_astronomy                         150.349057  131.482988
# tc_theoretical_physics               153.762438  131.482988
# tc_hidrology                         127.337291  132.228356
# tc_sensors_data_telescopy            141.436246  132.741619
# tc_geology                           138.947522  134.763602
# tc_psychiatry_mental_health          155.510857  136.737597
# tc_ionisation_plasma                 165.986852  140.545683
# tc_biopharmaceuticals                143.517856  141.896420
# tc_bio_informatics                   174.162821  160.938342
# tc_carbon_greenhouse_pollution       184.098722  165.380699
#
# [88 rows x 2 columns]

# %%
#Subset the edge list by type of organisation
org_lookup = {x:{'domain':d,'industry':ind} for x,d,ind in zip(final_org_set_2.index,
                                                               final_org_set_2.domain,
                                                               final_org_set_2.industry)}

#How is this going to work?
edge_list_with_coords['n1_domain'] = [org_lookup[x]['domain'] for x in edge_list_with_coords['e1']]
edge_list_with_coords['n2_domain'] = [org_lookup[x]['domain'] for x in edge_list_with_coords['e2']]

edge_list_with_coords['n1_industry'] = [org_lookup[x]['industry'] for x in edge_list_with_coords['e1']]
edge_list_with_coords['n2_industry'] = [org_lookup[x]['industry'] for x in edge_list_with_coords['e2']]



edge_list_with_coords['combination'] = ["_".join(sorted([x,y])) for x,y in zip(edge_list_with_coords['n1_domain'],
                                                                      edge_list_with_coords['n2_domain'])]

# %%
distances_org_types = edge_list_with_coords.groupby(['field','combination'])['distances'].median().reset_index(drop=False)

# %%
distances_wide = pd.pivot_table(distances_org_types,index='field',columns='combination',values='distances')

# %%
#Ok there might be something here
distances_wide.fillna(value=0,inplace=True)
distances_wide.sort_values('industry_industry')
# Out:
# combination                          Archive_Archive  Archive_Education  \
# field
# tc_linguistics                              0.000000           0.000000
# tc_political_history                        0.000000           0.000000
# tc_migration_colonial_history               0.000000           0.000000
# tc_sociology                                0.000000          44.234891
# tc_military_history                         0.000000           0.577514
# tc_philosophy                               0.000000           0.000000
# tc_architecture_spatial                     0.000000           0.000000
# tc_visual                                   0.000000         109.743719
# tc_gender_sexuality                         0.000000           0.000000
# tc_criminology_violence                     0.000000           0.000000
# tc_environment                              0.000000           0.000000
# tc_cyber_security                           0.000000           0.000000
# tc_medieval_modern_history                  0.000000           7.354056
# tc_computer_vision                          0.000000           0.000000
# tc_statistics_data_analysis                 0.000000           0.000000
# tc_nutrition_health                         0.000000           0.000000
# tc_development_studies                      0.000000           0.000000
# tc_genetics                                 0.000000           0.000000
# tc_networks                                 0.000000           0.000000
# tc_health_social_issues                     0.000000           0.000000
# tc_robotics_cybernetics                     0.000000           0.000000
# tc_reproduction_fertility                   0.000000           0.000000
# tc_education                                0.000000         161.998909
# tc_computer_science                         0.000000           0.000000
# tc_energy_transport_technology              0.000000           0.000000
# tc_mathematics                              0.000000           0.000000
# tc_biopharmaceuticals                       0.000000           0.000000
# tc_systems_infrastructure                   0.000000          50.453920
# tc_cognition_&_audio                        0.000000           0.000000
# tc_cellular_biology_cancer                  0.000000           0.000000
# ...                                              ...                ...
# tc_cosmology                                0.000000           0.000000
# tc_surgert_cardiology                       0.000000           0.000000
# tc_modelling_&_sensors                      0.000000           0.000000
# tc_law                                      0.000000          26.934835
# tc_health_interventions_policy              0.000000           0.000000
# tc_respiratory_system                       0.000000           0.000000
# tc_drug_tests                               0.000000           0.000000
# tc_psychiatry_mental_health                 0.000000           0.000000
# tc_social_history                           0.000000          85.141873
# tc_astrophysics                             0.000000           0.000000
# tc_geology                                  0.000000           0.000000
# tc_chemistry_biochemistry                   0.000000           0.000000
# tc_cells_cancer                             0.000000           0.000000
# tc_modelling_measurement                    0.000000           0.000000
# tc_energy_environmental                     0.000000           0.000000
# tc_imaging                                  0.000000           0.000000
# tc_carbon_greenhouse_pollution              0.000000          26.934835
# tc_astronomy                                0.000000           0.000000
# tc_ionisation_plasma                        0.000000           0.000000
# tc_experiments                              0.000000           0.000000
# tc_climate_science                        353.581451           1.768727
# tc_minerals_fuels                           0.000000           0.000000
# tc_public_engagement_infrastructure         0.000000           0.000000
# tc_hidrology                                0.000000         194.456390
# tc_epidemiology_immunology                  0.000000           0.000000
# tc_bio_informatics                          0.000000           0.000000
# tc_psychology                               0.000000           0.000000
# tc_literature                               0.000000           0.000000
# tc_neurology                                0.000000           0.000000
# tc_classic_religious_history                0.000000           0.000000
#
# combination                          Archive_Facility  Archive_Government  \
# field
# tc_linguistics                               0.000000            0.000000
# tc_political_history                         0.000000            0.000000
# tc_migration_colonial_history                0.000000            0.000000
# tc_sociology                                 0.000000            0.000000
# tc_military_history                          0.000000            0.000000
# tc_philosophy                                0.000000            0.000000
# tc_architecture_spatial                      0.000000            0.000000
# tc_visual                                    0.000000            0.000000
# tc_gender_sexuality                          0.000000            0.000000
# tc_criminology_violence                      0.000000            0.000000
# tc_environment                               0.000000            0.000000
# tc_cyber_security                            0.000000            0.000000
# tc_medieval_modern_history                   0.000000          336.930759
# tc_computer_vision                           0.000000            0.000000
# tc_statistics_data_analysis                  0.000000            0.000000
# tc_nutrition_health                          0.000000            0.000000
# tc_development_studies                       0.000000            0.000000
# tc_genetics                                  0.000000            0.000000
# tc_networks                                  0.000000            0.000000
# tc_health_social_issues                      0.000000            0.000000
# tc_robotics_cybernetics                      0.000000            0.000000
# tc_reproduction_fertility                    0.000000            0.000000
# tc_education                                 0.000000            0.000000
# tc_computer_science                          0.000000            0.000000
# tc_energy_transport_technology               0.000000            0.000000
# tc_mathematics                               0.000000            0.000000
# tc_biopharmaceuticals                        0.000000            0.000000
# tc_systems_infrastructure                  141.748399          108.554639
# tc_cognition_&_audio                         0.000000            0.000000
# tc_cellular_biology_cancer                   0.000000            0.000000
# ...                                               ...                 ...
# tc_cosmology                                 0.000000            0.000000
# tc_surgert_cardiology                        0.000000            0.000000
# tc_modelling_&_sensors                       0.000000            0.000000
# tc_law                                       0.000000          332.568732
# tc_health_interventions_policy               0.000000            0.000000
# tc_respiratory_system                        0.000000            0.000000
# tc_drug_tests                                0.000000            0.000000
# tc_psychiatry_mental_health                  0.000000            0.000000
# tc_social_history                            0.000000          111.317948
# tc_astrophysics                              0.000000            0.000000
# tc_geology                                   0.000000            0.000000
# tc_chemistry_biochemistry                    0.000000            0.000000
# tc_cells_cancer                              0.000000            0.000000
# tc_modelling_measurement                     0.000000            0.000000
# tc_energy_environmental                      0.000000            0.000000
# tc_imaging                                   0.000000            0.000000
# tc_carbon_greenhouse_pollution               0.000000          212.137908
# tc_astronomy                                 0.000000            0.000000
# tc_ionisation_plasma                         0.000000            0.000000
# tc_experiments                               0.000000            0.000000
# tc_climate_science                           0.000000          177.179003
# tc_minerals_fuels                            0.000000            0.000000
# tc_public_engagement_infrastructure          0.000000            0.000000
# tc_hidrology                                 0.000000          210.972035
# tc_epidemiology_immunology                   0.000000            0.000000
# tc_bio_informatics                           0.000000            0.000000
# tc_psychology                                0.000000            0.000000
# tc_literature                                0.000000            0.000000
# tc_neurology                                 0.000000            0.000000
# tc_classic_religious_history                 0.000000            0.000000
#
# combination                          Archive_Healthcare  Archive_Nonprofit  \
# field
# tc_linguistics                                 0.000000           0.000000
# tc_political_history                           0.000000           0.000000
# tc_migration_colonial_history                  0.000000           1.973122
# tc_sociology                                   0.000000           0.000000
# tc_military_history                            0.000000           0.000000
# tc_philosophy                                  0.000000           0.000000
# tc_architecture_spatial                        0.000000           0.000000
# tc_visual                                      0.000000           0.000000
# tc_gender_sexuality                            0.000000           0.000000
# tc_criminology_violence                        0.000000           0.000000
# tc_environment                                 0.000000           0.000000
# tc_cyber_security                              0.000000           0.000000
# tc_medieval_modern_history                     0.000000           0.000000
# tc_computer_vision                             0.000000           0.000000
# tc_statistics_data_analysis                    0.000000           0.000000
# tc_nutrition_health                            0.000000           0.000000
# tc_development_studies                         0.000000           0.000000
# tc_genetics                                    0.000000           0.000000
# tc_networks                                    0.000000           0.000000
# tc_health_social_issues                        0.000000           0.000000
# tc_robotics_cybernetics                        0.000000           0.000000
# tc_reproduction_fertility                      0.000000           0.000000
# tc_education                                   0.000000           0.000000
# tc_computer_science                            0.000000           0.000000
# tc_energy_transport_technology                 0.000000           0.000000
# tc_mathematics                                 0.000000           0.000000
# tc_biopharmaceuticals                          0.000000           0.000000
# tc_systems_infrastructure                     52.014774          23.001829
# tc_cognition_&_audio                           0.000000           0.000000
# tc_cellular_biology_cancer                     0.000000           0.000000
# ...                                                 ...                ...
# tc_cosmology                                   0.000000           0.000000
# tc_surgert_cardiology                          0.000000           0.000000
# tc_modelling_&_sensors                         0.000000           0.000000
# tc_law                                         0.000000           0.000000
# tc_health_interventions_policy                 0.000000           0.000000
# tc_respiratory_system                          0.000000           0.000000
# tc_drug_tests                                  0.000000           0.000000
# tc_psychiatry_mental_health                    0.000000           0.000000
# tc_social_history                              0.000000           0.000000
# tc_astrophysics                                0.000000           0.000000
# tc_geology                                     0.000000           0.000000
# tc_chemistry_biochemistry                      0.000000           0.000000
# tc_cells_cancer                                0.000000           0.000000
# tc_modelling_measurement                       0.000000           0.000000
# tc_energy_environmental                        0.000000           0.000000
# tc_imaging                                     0.000000           0.000000
# tc_carbon_greenhouse_pollution                 0.000000           0.000000
# tc_astronomy                                   0.000000           0.000000
# tc_ionisation_plasma                           0.000000           0.000000
# tc_experiments                                 0.000000           0.000000
# tc_climate_science                             0.000000           0.000000
# tc_minerals_fuels                              0.000000           0.000000
# tc_public_engagement_infrastructure            0.000000           0.000000
# tc_hidrology                                   0.000000           0.000000
# tc_epidemiology_immunology                     0.000000           0.000000
# tc_bio_informatics                             0.000000           0.000000
# tc_psychology                                  0.000000           0.000000
# tc_literature                                  0.000000           0.000000
# tc_neurology                                   0.000000           0.000000
# tc_classic_religious_history                   0.000000           0.000000
#
# combination                          Archive_Other  Archive_education  \
# field
# tc_linguistics                            0.000000           0.000000
# tc_political_history                      0.000000           0.000000
# tc_migration_colonial_history             0.000000          43.191862
# tc_sociology                              0.000000           0.000000
# tc_military_history                       0.000000           0.464574
# tc_philosophy                             0.000000           0.000000
# tc_architecture_spatial                   0.000000           0.000000
# tc_visual                                 0.000000           0.000000
# tc_gender_sexuality                       0.000000           0.000000
# tc_criminology_violence                   0.000000           0.000000
# tc_environment                            0.000000           0.000000
# tc_cyber_security                         0.000000           0.000000
# tc_medieval_modern_history                6.271288           5.973228
# tc_computer_vision                        0.000000           0.000000
# tc_statistics_data_analysis               0.000000           0.000000
# tc_nutrition_health                       0.000000           0.000000
# tc_development_studies                    0.000000           0.000000
# tc_genetics                               0.000000           0.000000
# tc_networks                               0.000000           0.000000
# tc_health_social_issues                   0.000000           0.000000
# tc_robotics_cybernetics                   0.000000           0.000000
# tc_reproduction_fertility                 0.000000           0.000000
# tc_education                              0.000000         141.686940
# tc_computer_science                       0.000000           0.000000
# tc_energy_transport_technology            0.000000           0.000000
# tc_mathematics                            0.000000           0.000000
# tc_biopharmaceuticals                     0.000000           0.000000
# tc_systems_infrastructure                 1.519808         164.331857
# tc_cognition_&_audio                      0.000000           0.000000
# tc_cellular_biology_cancer                0.000000           0.000000
# ...                                            ...                ...
# tc_cosmology                              0.000000           0.000000
# tc_surgert_cardiology                     0.000000           0.000000
# tc_modelling_&_sensors                    0.000000           0.000000
# tc_law                                    0.000000           0.000000
# tc_health_interventions_policy            0.000000           0.000000
# tc_respiratory_system                     0.000000           0.000000
# tc_drug_tests                             0.000000           0.000000
# tc_psychiatry_mental_health               0.000000           0.000000
# tc_social_history                         0.000000         110.538764
# tc_astrophysics                           0.000000           0.000000
# tc_geology                                0.000000           0.000000
# tc_chemistry_biochemistry                 0.000000           0.000000
# tc_cells_cancer                           0.000000           0.000000
# tc_modelling_measurement                  0.000000           0.000000
# tc_energy_environmental                   0.000000           0.000000
# tc_imaging                                0.000000           0.000000
# tc_carbon_greenhouse_pollution            0.000000           0.000000
# tc_astronomy                              0.000000           0.000000
# tc_ionisation_plasma                      0.000000           0.000000
# tc_experiments                            0.000000           0.000000
# tc_climate_science                        0.000000         173.757549
# tc_minerals_fuels                         0.000000           0.000000
# tc_public_engagement_infrastructure       0.000000           0.000000
# tc_hidrology                              0.000000           0.000000
# tc_epidemiology_immunology                0.000000           0.000000
# tc_bio_informatics                        0.000000           0.000000
# tc_psychology                             0.000000           0.000000
# tc_literature                             0.000000           0.000000
# tc_neurology                              0.000000           0.000000
# tc_classic_religious_history              0.000000           0.000000
#
# combination                          Archive_industry  Education_Education  \
# field
# tc_linguistics                              97.850255             0.000000
# tc_political_history                         0.000000           116.144308
# tc_migration_colonial_history                2.759849             0.000000
# tc_sociology                                62.895610           131.600284
# tc_military_history                          0.000000           151.293732
# tc_philosophy                                0.000000            35.563683
# tc_architecture_spatial                      0.000000            86.090404
# tc_visual                                    0.000000             0.000000
# tc_gender_sexuality                          0.000000             0.000000
# tc_criminology_violence                      0.000000             0.000000
# tc_environment                               0.000000           243.068592
# tc_cyber_security                            0.000000            91.832054
# tc_medieval_modern_history                  44.749484            96.135527
# tc_computer_vision                           0.000000            48.203597
# tc_statistics_data_analysis                  0.000000            48.203597
# tc_nutrition_health                          0.000000            95.859084
# tc_development_studies                       0.000000           188.043111
# tc_genetics                                  0.000000           157.608432
# tc_networks                                  0.000000           301.557972
# tc_health_social_issues                      0.000000           103.395274
# tc_robotics_cybernetics                      0.000000           345.098462
# tc_reproduction_fertility                    0.000000            99.898680
# tc_education                               162.066570           113.470484
# tc_computer_science                          0.000000           171.146215
# tc_energy_transport_technology               0.000000           170.017181
# tc_mathematics                               0.000000           129.586796
# tc_biopharmaceuticals                        0.000000             0.000000
# tc_systems_infrastructure                   24.796655           148.074853
# tc_cognition_&_audio                         0.000000           305.619093
# tc_cellular_biology_cancer                   0.000000            72.094359
# ...                                               ...                  ...
# tc_cosmology                                 0.000000           160.726649
# tc_surgert_cardiology                        0.000000            67.756687
# tc_modelling_&_sensors                       0.000000           149.482780
# tc_law                                     199.855585           107.926364
# tc_health_interventions_policy               0.000000           158.024827
# tc_respiratory_system                        0.000000           157.608432
# tc_drug_tests                                0.000000           101.051097
# tc_psychiatry_mental_health                  0.000000           132.951934
# tc_social_history                          178.848929            84.926647
# tc_astrophysics                              0.000000           106.869351
# tc_geology                                   0.000000           176.683530
# tc_chemistry_biochemistry                    0.000000           253.861313
# tc_cells_cancer                              0.000000           131.385086
# tc_modelling_measurement                     0.000000           131.385086
# tc_energy_environmental                      0.000000           160.726649
# tc_imaging                                   0.000000           187.376804
# tc_carbon_greenhouse_pollution             282.545458           290.333259
# tc_astronomy                                 0.000000           231.992473
# tc_ionisation_plasma                         0.000000           185.615662
# tc_experiments                               0.000000           132.133796
# tc_climate_science                           0.000000           149.482780
# tc_minerals_fuels                            0.000000           151.293732
# tc_public_engagement_infrastructure          0.000000           160.726649
# tc_hidrology                                86.688743            74.882995
# tc_epidemiology_immunology                   0.000000           116.144308
# tc_bio_informatics                           0.000000           188.225973
# tc_psychology                                0.000000           119.457179
# tc_literature                                0.000000             0.000000
# tc_neurology                                 0.000000            84.926647
# tc_classic_religious_history                 0.000000           187.376804
#
# combination                                ...          Nonprofit_Nonprofit  \
# field                                      ...
# tc_linguistics                             ...                     0.000000
# tc_political_history                       ...                     0.000000
# tc_migration_colonial_history              ...                     0.000000
# tc_sociology                               ...                     0.000000
# tc_military_history                        ...                   117.504478
# tc_philosophy                              ...                     0.000000
# tc_architecture_spatial                    ...                     0.000000
# tc_visual                                  ...                     0.000000
# tc_gender_sexuality                        ...                     0.000000
# tc_criminology_violence                    ...                     0.000000
# tc_environment                             ...                     0.000000
# tc_cyber_security                          ...                     0.000000
# tc_medieval_modern_history                 ...                    37.840806
# tc_computer_vision                         ...                     0.000000
# tc_statistics_data_analysis                ...                     0.000000
# tc_nutrition_health                        ...                     0.000000
# tc_development_studies                     ...                     0.000000
# tc_genetics                                ...                     0.000000
# tc_networks                                ...                     0.000000
# tc_health_social_issues                    ...                     0.000000
# tc_robotics_cybernetics                    ...                     0.000000
# tc_reproduction_fertility                  ...                     0.000000
# tc_education                               ...                     0.000000
# tc_computer_science                        ...                     0.000000
# tc_energy_transport_technology             ...                     0.000000
# tc_mathematics                             ...                     0.000000
# tc_biopharmaceuticals                      ...                     0.000000
# tc_systems_infrastructure                  ...                    46.187369
# tc_cognition_&_audio                       ...                     0.000000
# tc_cellular_biology_cancer                 ...                     0.000000
# ...                                        ...                          ...
# tc_cosmology                               ...                     0.000000
# tc_surgert_cardiology                      ...                     0.000000
# tc_modelling_&_sensors                     ...                     0.000000
# tc_law                                     ...                     0.000000
# tc_health_interventions_policy             ...                     0.000000
# tc_respiratory_system                      ...                     0.000000
# tc_drug_tests                              ...                     0.000000
# tc_psychiatry_mental_health                ...                     0.000000
# tc_social_history                          ...                   182.896292
# tc_astrophysics                            ...                     0.000000
# tc_geology                                 ...                     0.000000
# tc_chemistry_biochemistry                  ...                     0.000000
# tc_cells_cancer                            ...                     0.000000
# tc_modelling_measurement                   ...                     0.000000
# tc_energy_environmental                    ...                     0.000000
# tc_imaging                                 ...                     0.000000
# tc_carbon_greenhouse_pollution             ...                     0.000000
# tc_astronomy                               ...                     0.000000
# tc_ionisation_plasma                       ...                     0.000000
# tc_experiments                             ...                     0.000000
# tc_climate_science                         ...                     0.000000
# tc_minerals_fuels                          ...                     0.000000
# tc_public_engagement_infrastructure        ...                     0.000000
# tc_hidrology                               ...                     0.000000
# tc_epidemiology_immunology                 ...                     0.000000
# tc_bio_informatics                         ...                     0.000000
# tc_psychology                              ...                     0.000000
# tc_literature                              ...                     0.000000
# tc_neurology                               ...                     0.000000
# tc_classic_religious_history               ...                     0.000000
#
# combination                          Nonprofit_Other  Nonprofit_education  \
# field
# tc_linguistics                              0.000000             0.000000
# tc_political_history                        0.000000             0.000000
# tc_migration_colonial_history               0.000000            43.600971
# tc_sociology                              171.896840           331.330797
# tc_military_history                         0.000000            41.218614
# tc_philosophy                               0.000000             0.000000
# tc_architecture_spatial                     0.000000             0.000000
# tc_visual                                   0.000000             0.000000
# tc_gender_sexuality                         0.000000             0.000000
# tc_criminology_violence                    82.069953           110.261158
# tc_environment                              0.000000             6.127704
# tc_cyber_security                           0.000000             0.000000
# tc_medieval_modern_history                  0.000000            21.735948
# tc_computer_vision                          0.000000             0.000000
# tc_statistics_data_analysis                 0.000000             0.000000
# tc_nutrition_health                         0.000000             0.000000
# tc_development_studies                      0.000000             0.000000
# tc_genetics                                 0.000000             0.000000
# tc_networks                                 0.000000             0.000000
# tc_health_social_issues                     0.000000             0.000000
# tc_robotics_cybernetics                     0.000000             0.000000
# tc_reproduction_fertility                   0.000000             0.000000
# tc_education                               15.681760             2.954163
# tc_computer_science                         0.000000            97.765007
# tc_energy_transport_technology              0.000000           257.714823
# tc_mathematics                              0.000000           140.936204
# tc_biopharmaceuticals                       0.000000             0.000000
# tc_systems_infrastructure                  46.163187           141.542097
# tc_cognition_&_audio                        0.000000             0.000000
# tc_cellular_biology_cancer                  0.000000             0.000000
# ...                                              ...                  ...
# tc_cosmology                                0.000000             0.000000
# tc_surgert_cardiology                       0.000000             0.000000
# tc_modelling_&_sensors                      0.000000             0.000000
# tc_law                                      0.000000             0.000000
# tc_health_interventions_policy              0.000000             3.296026
# tc_respiratory_system                       0.000000             0.000000
# tc_drug_tests                               0.000000             4.604857
# tc_psychiatry_mental_health                 0.000000           142.502657
# tc_social_history                         250.700401           141.439414
# tc_astrophysics                             0.000000             0.000000
# tc_geology                                  0.000000             0.000000
# tc_chemistry_biochemistry                   0.000000             0.000000
# tc_cells_cancer                             0.000000             0.000000
# tc_modelling_measurement                    0.000000             0.000000
# tc_energy_environmental                     0.000000           108.347066
# tc_imaging                                  0.000000             0.000000
# tc_carbon_greenhouse_pollution              0.000000             0.221729
# tc_astronomy                                0.000000             0.000000
# tc_ionisation_plasma                        0.000000             0.000000
# tc_experiments                              0.000000             0.000000
# tc_climate_science                          0.000000             0.000000
# tc_minerals_fuels                           0.000000             0.000000
# tc_public_engagement_infrastructure         0.000000             0.000000
# tc_hidrology                                0.000000             0.000000
# tc_epidemiology_immunology                  0.000000             0.000000
# tc_bio_informatics                          0.000000             0.000000
# tc_psychology                               0.000000           173.775038
# tc_literature                               0.000000            51.289934
# tc_neurology                                0.000000             0.000000
# tc_classic_religious_history                0.000000             0.000000
#
# combination                          Nonprofit_industry  Other_Other  \
# field
# tc_linguistics                                 0.000000     0.000000
# tc_political_history                           0.000000     0.000000
# tc_migration_colonial_history                  1.211095     0.000000
# tc_sociology                                  40.239347     0.000000
# tc_military_history                           58.871721     0.000000
# tc_philosophy                                  0.000000     0.000000
# tc_architecture_spatial                        0.000000     0.000000
# tc_visual                                      0.000000     0.000000
# tc_gender_sexuality                            0.000000     0.000000
# tc_criminology_violence                      104.796916     0.000000
# tc_environment                                 0.000000     0.000000
# tc_cyber_security                              6.159437     0.000000
# tc_medieval_modern_history                   247.955177     0.000000
# tc_computer_vision                             0.000000     0.000000
# tc_statistics_data_analysis                    0.000000     0.000000
# tc_nutrition_health                            0.000000     0.000000
# tc_development_studies                         0.000000     0.000000
# tc_genetics                                    0.000000     0.000000
# tc_networks                                   29.664658     0.000000
# tc_health_social_issues                        0.000000     0.000000
# tc_robotics_cybernetics                        0.000000     0.000000
# tc_reproduction_fertility                      0.000000     0.000000
# tc_education                                   2.475305     0.000000
# tc_computer_science                           28.862574     0.000000
# tc_energy_transport_technology               243.350198     0.000000
# tc_mathematics                                87.203534     0.000000
# tc_biopharmaceuticals                          0.000000     0.000000
# tc_systems_infrastructure                     45.959489     0.412291
# tc_cognition_&_audio                           0.000000     0.000000
# tc_cellular_biology_cancer                     0.000000     0.000000
# ...                                                 ...          ...
# tc_cosmology                                  51.645861     0.000000
# tc_surgert_cardiology                          0.000000     0.000000
# tc_modelling_&_sensors                         0.000000     0.000000
# tc_law                                        45.596331     0.000000
# tc_health_interventions_policy               107.861902     0.000000
# tc_respiratory_system                          0.000000     0.000000
# tc_drug_tests                                 88.735440     0.000000
# tc_psychiatry_mental_health                  248.545909     0.000000
# tc_social_history                             89.532682   168.234404
# tc_astrophysics                                0.000000     0.000000
# tc_geology                                     0.000000     0.000000
# tc_chemistry_biochemistry                      0.000000     0.000000
# tc_cells_cancer                               67.834459     0.000000
# tc_modelling_measurement                      97.088222     0.000000
# tc_energy_environmental                       59.271273     0.000000
# tc_imaging                                     0.000000     0.000000
# tc_carbon_greenhouse_pollution               148.869624     0.000000
# tc_astronomy                                   0.000000     0.000000
# tc_ionisation_plasma                           0.000000     0.000000
# tc_experiments                                 0.000000     0.000000
# tc_climate_science                           151.841093     0.000000
# tc_minerals_fuels                              0.000000     0.000000
# tc_public_engagement_infrastructure           55.883638     0.000000
# tc_hidrology                                   0.000000     0.000000
# tc_epidemiology_immunology                     0.000000     0.000000
# tc_bio_informatics                             0.000000     0.000000
# tc_psychology                                  0.000000     0.000000
# tc_literature                                 68.919492     0.000000
# tc_neurology                                   0.000000     0.000000
# tc_classic_religious_history                   0.000000     0.000000
#
# combination                          Other_education  Other_industry  \
# field
# tc_linguistics                              0.000000        0.000000
# tc_political_history                        0.000000        0.000000
# tc_migration_colonial_history               0.000000        0.000000
# tc_sociology                                0.000000       13.928117
# tc_military_history                         0.000000        0.000000
# tc_philosophy                               0.000000        0.000000
# tc_architecture_spatial                     0.000000        0.000000
# tc_visual                                   0.000000      162.995168
# tc_gender_sexuality                         0.000000        0.000000
# tc_criminology_violence                     0.000000       22.741454
# tc_environment                              0.000000        0.000000
# tc_cyber_security                           0.000000        0.000000
# tc_medieval_modern_history                142.222279       49.989192
# tc_computer_vision                          0.000000        0.000000
# tc_statistics_data_analysis                 0.000000      108.607338
# tc_nutrition_health                         0.000000        0.000000
# tc_development_studies                      0.000000        0.000000
# tc_genetics                                 0.000000        0.000000
# tc_networks                                 0.000000        0.000000
# tc_health_social_issues                     0.000000        0.000000
# tc_robotics_cybernetics                     0.000000        0.000000
# tc_reproduction_fertility                   0.000000        0.000000
# tc_education                               13.777579       14.887705
# tc_computer_science                         0.000000        0.000000
# tc_energy_transport_technology              0.000000        0.000000
# tc_mathematics                              0.000000        0.000000
# tc_biopharmaceuticals                       0.000000        0.000000
# tc_systems_infrastructure                 163.114396       50.541108
# tc_cognition_&_audio                        0.000000        0.000000
# tc_cellular_biology_cancer                  0.000000        0.000000
# ...                                              ...             ...
# tc_cosmology                                0.000000        0.000000
# tc_surgert_cardiology                       0.000000        0.000000
# tc_modelling_&_sensors                      0.000000      151.567216
# tc_law                                      0.000000        0.000000
# tc_health_interventions_policy              0.000000      107.695669
# tc_respiratory_system                       0.000000        0.000000
# tc_drug_tests                               0.000000        0.000000
# tc_psychiatry_mental_health                 0.000000        0.000000
# tc_social_history                         142.875694      140.981536
# tc_astrophysics                             0.000000        0.000000
# tc_geology                                  0.000000        0.000000
# tc_chemistry_biochemistry                   0.000000        2.484065
# tc_cells_cancer                             0.000000        0.000000
# tc_modelling_measurement                    0.000000        0.000000
# tc_energy_environmental                     0.000000       88.610355
# tc_imaging                                  0.000000        0.000000
# tc_carbon_greenhouse_pollution            190.916956        0.000000
# tc_astronomy                                0.000000        0.000000
# tc_ionisation_plasma                        0.000000        0.000000
# tc_experiments                              0.000000        0.000000
# tc_climate_science                        153.685959       42.191330
# tc_minerals_fuels                          85.698807       93.626362
# tc_public_engagement_infrastructure         0.000000       36.943249
# tc_hidrology                               40.528973       89.179779
# tc_epidemiology_immunology                235.465303      196.950812
# tc_bio_informatics                          0.000000      102.921244
# tc_psychology                             174.314779       52.135874
# tc_literature                               0.000000        0.000000
# tc_neurology                                0.000000        0.000000
# tc_classic_religious_history                0.000000      143.188868
#
# combination                          education_education  education_industry  \
# field
# tc_linguistics                                  0.000000           44.595181
# tc_political_history                          142.282204           91.522971
# tc_migration_colonial_history                  30.665236           42.371503
# tc_sociology                                  288.932716          128.655775
# tc_military_history                           195.714331            1.186010
# tc_philosophy                                  82.864390            4.332329
# tc_architecture_spatial                         0.000000            2.245478
# tc_visual                                       0.000000           89.456683
# tc_gender_sexuality                           187.527885           84.605068
# tc_criminology_violence                         0.000000          100.122925
# tc_environment                                  0.000000           10.030589
# tc_cyber_security                               0.000000          141.772460
# tc_medieval_modern_history                    141.329365           60.268823
# tc_computer_vision                             93.593100          152.870960
# tc_statistics_data_analysis                     0.000000          140.513828
# tc_nutrition_health                             0.000000           25.158283
# tc_development_studies                          0.000000           44.161660
# tc_genetics                                     0.000000            0.000000
# tc_networks                                    43.095495           59.644026
# tc_health_social_issues                         0.000000            1.248135
# tc_robotics_cybernetics                       189.630275          102.639956
# tc_reproduction_fertility                     141.329365           65.785919
# tc_education                                  140.889671           65.785919
# tc_computer_science                             0.000000           92.871052
# tc_energy_transport_technology                330.958561           68.771439
# tc_mathematics                                141.526866          104.722136
# tc_biopharmaceuticals                           0.000000          173.042444
# tc_systems_infrastructure                      98.181724           92.167748
# tc_cognition_&_audio                            0.000000          104.767845
# tc_cellular_biology_cancer                    130.852469          106.375439
# ...                                                  ...                 ...
# tc_cosmology                                    6.139424          101.478728
# tc_surgert_cardiology                          73.734394          161.255438
# tc_modelling_&_sensors                          0.000000          152.040378
# tc_law                                         40.319649          140.802499
# tc_health_interventions_policy                141.329365          104.722136
# tc_respiratory_system                         141.329365          108.409804
# tc_drug_tests                                 142.282204           91.778158
# tc_psychiatry_mental_health                   156.325503          152.040378
# tc_social_history                             172.983844          141.015523
# tc_astrophysics                                42.818000           71.543876
# tc_geology                                     43.978528          106.915331
# tc_chemistry_biochemistry                     330.958561          125.908655
# tc_cells_cancer                               141.329365          109.435097
# tc_modelling_measurement                        6.139424           74.133371
# tc_energy_environmental                       135.808069          128.446925
# tc_imaging                                    133.781246          104.722136
# tc_carbon_greenhouse_pollution                279.650272          176.906787
# tc_astronomy                                   42.818000           54.521420
# tc_ionisation_plasma                          173.190137          118.437929
# tc_experiments                                  0.000000            0.000000
# tc_climate_science                             82.170166          109.247519
# tc_minerals_fuels                              53.402827          112.974548
# tc_public_engagement_infrastructure            60.760470           88.871384
# tc_hidrology                                    6.139424          104.263943
# tc_epidemiology_immunology                      0.000000           88.567138
# tc_bio_informatics                             28.372045          101.355107
# tc_psychology                                 142.282204          110.683699
# tc_literature                                   0.000000           60.398351
# tc_neurology                                    0.000000            0.000000
# tc_classic_religious_history                   12.158704           16.603431
#
# combination                          industry_industry
# field
# tc_linguistics                                0.000000
# tc_political_history                          0.000000
# tc_migration_colonial_history                 0.761819
# tc_sociology                                  1.455329
# tc_military_history                           1.859295
# tc_philosophy                                 3.029536
# tc_architecture_spatial                       3.481790
# tc_visual                                    11.765046
# tc_gender_sexuality                          11.991397
# tc_criminology_violence                      16.170040
# tc_environment                               16.401284
# tc_cyber_security                            17.717174
# tc_medieval_modern_history                   48.418273
# tc_computer_vision                           48.695436
# tc_statistics_data_analysis                  51.574985
# tc_nutrition_health                          51.743498
# tc_development_studies                       53.798997
# tc_genetics                                  58.505584
# tc_networks                                  59.572621
# tc_health_social_issues                      63.345117
# tc_robotics_cybernetics                      63.365509
# tc_reproduction_fertility                    63.777068
# tc_education                                 63.777068
# tc_computer_science                          67.194677
# tc_energy_transport_technology               68.137145
# tc_mathematics                               71.483149
# tc_biopharmaceuticals                        71.659955
# tc_systems_infrastructure                    73.893647
# tc_cognition_&_audio                         74.514437
# tc_cellular_biology_cancer                   78.754244
# ...                                                ...
# tc_cosmology                                102.185692
# tc_surgert_cardiology                       102.185692
# tc_modelling_&_sensors                      103.646610
# tc_law                                      106.935302
# tc_health_interventions_policy              106.969744
# tc_respiratory_system                       107.638010
# tc_drug_tests                               107.638010
# tc_psychiatry_mental_health                 107.638010
# tc_social_history                           108.503661
# tc_astrophysics                             108.696385
# tc_geology                                  112.391639
# tc_chemistry_biochemistry                   113.080717
# tc_cells_cancer                             118.843188
# tc_modelling_measurement                    120.760500
# tc_energy_environmental                     120.760500
# tc_imaging                                  125.321883
# tc_carbon_greenhouse_pollution              125.321883
# tc_astronomy                                125.321883
# tc_ionisation_plasma                        125.321883
# tc_experiments                              125.321883
# tc_climate_science                          126.182635
# tc_minerals_fuels                           128.529012
# tc_public_engagement_infrastructure         129.331534
# tc_hidrology                                133.640797
# tc_epidemiology_immunology                  141.811339
# tc_bio_informatics                          152.963854
# tc_psychology                               152.963854
# tc_literature                               179.120090
# tc_neurology                                223.637219
# tc_classic_religious_history                276.433085
#
# [88 rows x 45 columns]

# %%
#distances_wide.sort_values('education_industry')

# %%
#Next steps
#Revise the geocoding - why do so many educational/policy orgs we identified through grid drop out?
#Consider differences in geo-distance between projects involving more than 1 discipline (taking into account
#the discipline distances distance). This would almost be like a two by two comparing projects with
#more than x disciplines where the average distance between disciplines is y with disciplines with more than x
#collabs where the average distance is w

# %%
#Could I create another network of collaboration between industries
#Could I visualise the geography of this network?
#Subsetting the network for local and wider collaborations?
