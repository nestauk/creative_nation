# %% [markdown]
# # GlassAI data
#
# This notebook explores data obtained from GlassAI
#
# I want to understand the data.
# * Key variables (to document)
# * Questions for them
# * Interesting questions we could explore with these data
# * Validation vs official data by sector
#
# ...

# %% [markdown]
# ## Preamble

# %%
# %matplotlib inline
#Imports

#Key imports are loaded from my profile (see standard_imports.py in src folder).

#Paths

#Paths
top = os.path.dirname(os.getcwd())

#External data (to download the GRID database)
ext_data = os.path.join(top,'data/external')

#Interim data (to place seed etc)
int_data = os.path.join(top,'data/interim/')

#Figures
fig_path = os.path.join(top,'reports/figures')

#Models
mod_path = os.path.join(top,'models/')

#Visualisations
viz_path = os.path.join(top,'src/visualization')


#Get date for saving files
today = datetime.datetime.today()

today_str = "_".join([str(x) for x in [today.day,today.month,today.year]])

# %%
import string
digits = string.digits

# %%
#Utilities
#This function takes a df with levels of activity and creates one with location quotients.

def sum_elements_in_list_of_lists(list_of_lists):
    '''
    Some times we have lists whose elements are lists of lists (eg a tokenised corpus) where we want to 
    extract the distribution.
    This function does that
    '''
    
    out_sorted = pd.Series([x for el in list_of_lists for x in el]).value_counts(ascending=False)
    return(out_sorted)
    

def create_lq_df(df):
    '''
    Takes a df with cells = activity in col in row and returns a df with cells = lq
    
    '''
    
    area_activity = df.sum(axis=0)
    area_shares = area_activity/area_activity.sum()
    
    lqs = df.apply(lambda x: (x/x.sum())/area_shares, axis=1)
    return(lqs)

# %% [markdown]
# ## 1. Load data

# %%
#Read Glass AI data
#Read and lowercase columns
glai_columns= [x.lower() for x in ['id','name','GeneratedSector','GeneratedSubsector','GeneratedTag',
          'SourceSector','SourceSubsector','Status','PredictedSector','Topics','PostalTowns','Website']]

#Read data
data = pd.read_csv(ext_data+'/org_creative_by_subsectors_v2.txt',sep='\t',header=None)

#Read detailed topic info we were sent
topics = pd.read_csv(ext_data+'/org_creative_topics.txt',sep='\t',header=None)

#Read detailed descriptions we were sent
descs = pd.read_csv(ext_data+'/org_creative_descriptions.txt',sep='\t',header=None)

#Rename data columns
data.columns=glai_columns

# %%
#Shape
#Around 253K companies
data.shape
# Out:
# (253650, 12)

# %%
#Merge data with descriptions
data2 = pd.merge(data,descs,left_on='id',right_on=0).drop(0,axis=1)

#And rename the description variables
data2.rename(columns={1:'desc_1',2:'desc_2'},inplace=True)

# %%
#For each company, gather the topics by id into lists and merge the result with our data
topics_gathered = topics.groupby(1)[0].apply(lambda x: list(x))
data3 = pd.concat([data2.set_index('id'),topics_gathered],1)

data3.rename(columns={0:'topics_detailed'},inplace=True)

# %%
#Get value counts for categorical variables (where the total number of values is less than 100).
#NB we remove topics detailed from the count because value counts doesn't work with a list
value_counts = [[x,data3.loc[:,x].value_counts()] for x in data3.columns.drop('topics_detailed') 
                if len(set(data3.loc[:,x]))<100]

#And print them
for x in value_counts:
    print(x[0])
    print('====')
    print(x[1])
    print('\n')
# Out:
# generatedsector
# ====
# Media and Arts                  77180
# Technology                      77106
# Professional Services           65311
# Consumer Goods and Services     21948
# Real Estate and Construction    11123
# Non Profit and Education          982
# Name: generatedsector, dtype: int64
#
#
# generatedsubsector
# ====
# Information Technology and Services    34025
# Marketing and Advertising              30885
# Design                                 26894
# Internet                               25471
# Computer Software                      15369
# Apparel and Fashion                    13128
# Music                                  12745
# Arts and Crafts                        12477
# Architecture and Planning              11123
# Photography                             9983
# Newspapers and Magazines                8892
# Luxury Goods and Jewellery              8820
# Media Production                        8262
# Publishing                              7190
# Motion Pictures and Film                5004
# Broadcast Media (TV, Radio)             4625
# Online Media                            4203
# Public Relations and Communications     4055
# Writing and Editing                     3034
# Computer Games                          2241
# Market Research                         1997
# Translation                             1480
# Museums                                  807
# Animation                                765
# Libraries                                175
# Name: generatedsubsector, dtype: int64
#
#
# generatedtag
# ====
# R1    129940
# R2    123710
# Name: generatedtag, dtype: int64
#
#
# sourcesector
# ====
# Technology                      24451
# Professional Services           21371
# Media and Arts                  15917
# Real Estate and Construction     5090
# Consumer Goods and Services      4278
# Non Profit and Education         1985
# Leisure and Hospitality          1197
# Industrial and Agriculture        844
# Financial Services                593
# Energy and Environmental          469
# Supply Chain and Transport        373
# Healthcare and Scientific         352
# Government                        105
# Name: sourcesector, dtype: int64
#
#
# status
# ====
# U    248780
# C      4870
# Name: status, dtype: int64

# %% [markdown]
# Some initial questions:
# * What is the difference between sourcesector and generated sector?
# * What do U and C mean?

# %% [markdown]
# ## Initial topic exploration

# %%
#Check the topics

#Split them into lists of topics unless they are nan
data3['topics_list'] = [x.split(",") if type(x)==str else [] for x in data3.topics]

#How many companies with missing topics do we have?
np.sum([len(x)==0 for x in data3.topics_list])/len(data3)
# Out:
# 0.55052631578947364

# %% [markdown]
# We have topics for 55% of the companies in the dataset.

# %%
data3['has_topic'] = [len(x)>0 for x in data3.topics_list]

# %%
#Plot
pd.crosstab(data3['has_topic'],
            data3['generatedsubsector'],normalize=1).T.sort_values(True).plot.barh(title='Distribution of sectors/ with topics')

# %%
#What are the top topics (and by sector)
#This is the total topic count
all_topics_distr = sum_elements_in_list_of_lists(data3.topics_list)

#Glass AI seem to be picking up popular ngrams that companies use to sell stuff.
all_topics_distr[:10]
# Out:
# high quality        1466
# social media        1170
# long term            532
# best possible        483
# high profile         476
# interior design      473
# brand new            457
# web design           437
# graphic design       430
# customer service     422
# dtype: int64

# %%
#Create a topic as share of all topics variable we can use to normalise inside subsectors (a bit like tfidf)
all_topics_share = pd.DataFrame(all_topics_distr/all_topics_distr.sum())
all_topics_share.columns=['share_all']

# %%
#Get top topics by sector
#NB we are normalising by the share of topics in the total to find topics which are more relevant for a sector.

#These are the top keywords by sector.
top_keywords_by_sector = data3.groupby('generatedsubsector')['topics_list'].apply(lambda x: pd.Series(
    [t for el in x for t in el]).value_counts(ascending=False)).reset_index(drop=False)

for x in set(top_keywords_by_sector.generatedsubsector):
    print(x)
    print('='*len(x))
    
    topics_in_sector = top_keywords_by_sector.loc[
        top_keywords_by_sector.generatedsubsector==x,[
            'level_1','topics_list']].set_index('level_1').sort_values('topics_list',ascending=False)[:25]
    
    
    topics_in_sector['share_in_sector'] = topics_in_sector/topics_in_sector.sum()
    
    topics_in_sector_norm = topics_in_sector.join(all_topics_share)
    
    topics_in_sector_norm['share_norm'] = topics_in_sector_norm['share_in_sector']/topics_in_sector_norm['share_all']
    
    print(topics_in_sector_norm.sort_values('share_norm',ascending=False)[:10])
    
    print('\n')
# Out:
# Translation
# ===========
#                            topics_list  share_in_sector  share_all  \
# level_1
# certified translation               12         0.025424   0.000020
# reliable translation                12         0.025424   0.000020
# professional translators            13         0.027542   0.000022
# language service provider           16         0.033898   0.000026
# translation solutions               10         0.021186   0.000017
# interpreting services               20         0.042373   0.000033
# quality translation                 37         0.078390   0.000063
# professional translation            29         0.061441   0.000050
# translation projects                18         0.038136   0.000031
# translation company                 17         0.036017   0.000030
#
#                             share_norm
# level_1
# certified translation      1280.760593
# reliable translation       1280.760593
# professional translators   1280.760593
# language service provider  1280.760593
# translation solutions      1280.760593
# interpreting services      1280.760593
# quality translation        1247.056367
# professional translation   1238.068573
# translation projects       1213.352141
# translation company        1209.607227
#
#
# Publishing
# ==========
#                         topics_list  share_in_sector  share_all  share_norm
# level_1
# independent publishing           15         0.027778   0.000028  987.776144
# independent publisher            41         0.075926   0.000081  936.707445
# crime fiction                    17         0.031481   0.000035  906.245414
# picture book                     30         0.055556   0.000083  671.687778
# debut novel                      15         0.027778   0.000041  671.687778
# book publisher                   17         0.031481   0.000050  634.371790
# short stories                    26         0.048148   0.000076  632.749356
# publishing houses                23         0.042593   0.000074  572.178477
# open access                      14         0.025926   0.000058  447.791852
# contract publishing              14         0.025926   0.000060  435.353189
#
#
# Market Research
# ===============
#                        topics_list  share_in_sector  share_all   share_norm
# level_1
# research executive              20         0.048544   0.000036  1333.890115
# research panel                  12         0.029126   0.000023  1257.667822
# custom research                 11         0.026699   0.000022  1241.543876
# quantitative research           35         0.084951   0.000078  1092.654668
# research consultancy            25         0.060680   0.000056  1078.881710
# mystery shopping                21         0.050971   0.000051   993.963279
# research techniques             16         0.038835   0.000040   978.186084
# qualitative research            32         0.077670   0.000083   939.058641
# research agency                 26         0.063107   0.000068   930.469690
# media research                  11         0.026699   0.000031   849.477389
#
#
# Newspapers and Magazines
# ========================
#                     topics_list  share_in_sector  share_all  share_norm
# level_1
# weekly newspaper             27         0.053360   0.000056  948.733608
# community news               16         0.031621   0.000035  910.248824
# tabloid newspaper            18         0.035573   0.000040  896.026186
# town council                 22         0.043478   0.000056  773.042199
# local people                 20         0.039526   0.000071  555.675154
# local newspaper              21         0.041502   0.000081  512.014963
# business directory           21         0.041502   0.000084  491.935945
# fa cup                       18         0.035573   0.000074  477.880632
# liberal democrat             18         0.035573   0.000076  467.491923
# general election             20         0.039526   0.000086  459.500608
#
#
# Writing and Editing
# ===================
#                         topics_list  share_in_sector  share_all   share_norm
# level_1
# dissertation help                15         0.061983   0.000025  2498.012397
# quality dissertation              6         0.024793   0.000010  2498.012397
# dissertation writing             10         0.041322   0.000018  2270.920361
# academic writing                 18         0.074380   0.000035  2141.153483
# essay writing                     9         0.037190   0.000022  1729.393198
# tender writing                    9         0.037190   0.000022  1729.393198
# professional writing              8         0.033058   0.000020  1665.341598
# writing service                  17         0.070248   0.000043  1633.315798
# transcription services            6         0.024793   0.000017  1498.807438
# technical writing                 6         0.024793   0.000023  1070.576741
#
#
# Architecture and Planning
# =========================
#                           topics_list  share_in_sector  share_all  share_norm
# level_1
# architectural technician           40         0.022870   0.000071  321.522731
# sustainable home                   48         0.027444   0.000086  319.049479
# full architectural                 69         0.039451   0.000124  317.985981
# architectural practice            196         0.112064   0.000362  309.337166
# town planning                      74         0.042310   0.000137  308.158232
# urban design                       82         0.046884   0.000154  304.755147
# residential scheme                 52         0.029731   0.000098  304.629163
# planning consultancy               41         0.023442   0.000079  295.231549
# residential project                61         0.034877   0.000122  284.916933
# mixed use                          45         0.025729   0.000093  277.743966
#
#
# Marketing and Advertising
# =========================
#                        topics_list  share_in_sector  share_all  share_norm
# level_1
# direct marketing                82         0.027554   0.000179  154.229384
# marketing solution              77         0.025874   0.000175  147.557704
# marketing plan                  72         0.024194   0.000167  144.806531
# lead generation                141         0.047379   0.000331  143.207626
# marketing consultancy           84         0.028226   0.000199  142.191969
# direct mail                     74         0.024866   0.000182  136.652022
# marketing agency               142         0.047715   0.000356  134.161193
# marketing service               88         0.029570   0.000225  131.437955
# marketing campaigns            103         0.034610   0.000276  125.284626
# email marketing                 87         0.029234   0.000237  123.583430
#
#
# Online Media
# ============
#                     topics_list  share_in_sector  share_all   share_norm
# level_1
# exceptional people           14         0.046053   0.000038  1210.421339
# static caravan                9         0.029605   0.000026  1118.559005
# wider technology             14         0.046053   0.000043  1070.757338
# personal line                14         0.046053   0.000051   898.054542
# caravan holiday               9         0.029605   0.000041   715.877763
# top secret                    8         0.026316   0.000069   378.771303
# chief executive              10         0.032895   0.000167   196.886073
# united kingdom               11         0.036184   0.000255   142.039239
# next year                     9         0.029605   0.000242   122.581809
# young person                 10         0.032895   0.000285   115.613334
#
#
# Design
# ======
#                     topics_list  share_in_sector  share_all  share_norm
# level_1
# kitchen design               85         0.041585   0.000157  264.621047
# bespoke kitchen              45         0.022016   0.000091  241.979674
# garden design               143         0.069961   0.000313  223.770739
# soft furnishings             47         0.022994   0.000117  195.780112
# design consultancy          115         0.056262   0.000293  192.155862
# bespoke furniture            43         0.021037   0.000111  189.811585
# interior design             298         0.145793   0.000782  186.330602
# garden designer              43         0.021037   0.000116  181.676803
# interior designers           42         0.020548   0.000116  177.451761
# logo design                  64         0.031311   0.000192  163.174033
#
#
# Internet
# ========
#                             topics_list  share_in_sector  share_all  \
# level_1
# web hosting                          53         0.033146   0.000190
# web design                          201         0.125704   0.000723
# web designer                         63         0.039400   0.000248
# bespoke web                          39         0.024390   0.000154
# search engine optimisation           71         0.044403   0.000298
# content management system            72         0.045028   0.000311
# web development                      71         0.044403   0.000319
# web presence                         36         0.022514   0.000164
# search engine                       116         0.072545   0.000589
# digital agency                       59         0.036898   0.000367
#
#                             share_norm
# level_1
# web hosting                 174.236653
# web design                  173.890602
# web designer                158.785478
# bespoke web                 158.541568
# search engine optimisation  149.123928
# content management system   144.789190
# web development             139.079311
# web presence                137.476605
# search engine               123.188306
# digital agency              100.475582
#
#
# Computer Software
# =================
#                       topics_list  share_in_sector  share_all  share_norm
# level_1
# bespoke mobile                 42         0.034855   0.000084  413.144545
# quality software               40         0.033195   0.000112  295.103246
# bespoke software               63         0.052282   0.000220  237.635772
# software solution             113         0.093776   0.000442  212.319602
# software developer             54         0.044813   0.000222  202.167746
# software engineering           34         0.028216   0.000146  193.829178
# new feature                    32         0.026556   0.000155  170.783155
# business processes             37         0.030705   0.000189  162.824510
# data capture                   35         0.029046   0.000205  141.601961
# web application                38         0.031535   0.000265  119.147936
#
#
# Information Technology and Services
# ===================================
#                       topics_list  share_in_sector  share_all  share_norm
# level_1
# computer repair                84         0.033058   0.000154  214.882787
# data recovery                  80         0.031484   0.000155  202.473143
# disaster recovery             106         0.041716   0.000208  200.143095
# business continuity            89         0.035026   0.000194  180.971187
# cyber security                142         0.055884   0.000314  177.803389
# hard drive                    126         0.049587   0.000280  177.373661
# data centres                   93         0.036600   0.000222  165.113826
# technology solution            95         0.037387   0.000233  160.291238
# information security           78         0.030697   0.000192  159.971237
# support service                86         0.033845   0.000242  140.136377
#
#
# Public Relations and Communications
# ===================================
#                             topics_list  share_in_sector  share_all  \
# level_1
# public relations agency              23         0.019377   0.000045
# crisis communication                 48         0.040438   0.000098
# media relation                       99         0.083404   0.000220
# communications programme             33         0.027801   0.000076
# press office                         40         0.033698   0.000093
# communications consultancy           59         0.049705   0.000139
# communications campaigns             29         0.024431   0.000071
# media training                       26         0.021904   0.000069
# reputation management                33         0.027801   0.000089
# public affairs                       61         0.051390   0.000167
#
#                             share_norm
# level_1
# public relations agency     433.833723
# crisis communication        414.331986
# media relation              379.090403
# communications programme    365.355243
# press office                363.773619
# communications consultancy  357.710725
# communications campaigns    343.469975
# media training              315.270470
# reputation management       311.228541
# public affairs              307.586803
#
#
# Media Production
# ================
#                             topics_list  share_in_sector  share_all  \
# level_1
# wedding video                        16         0.024883   0.000030
# video productions                    20         0.031104   0.000055
# corporate videos                     18         0.027994   0.000051
# corporate video production           23         0.035770   0.000071
# quality video                        22         0.034215   0.000069
# video marketing                      21         0.032659   0.000071
# promotional video                    31         0.048212   0.000106
# camera operator                      17         0.026439   0.000061
# production services                  20         0.031104   0.000076
# motion graphic                       35         0.054432   0.000154
#
#                             share_norm
# level_1
# wedding video               835.692414
# video productions           569.790282
# corporate videos            545.895851
# corporate video production  502.873051
# quality video               492.461601
# video marketing             459.144960
# promotional video           455.387077
# camera operator             431.962633
# production services         408.762594
# motion graphic              353.821385
#
#
# Music
# =====
#                        topics_list  share_in_sector  share_all  share_norm
# level_1
# professional musician           44         0.044400   0.000076  583.486948
# string quartet                  37         0.037336   0.000068  550.496001
# sheet music                     26         0.026236   0.000051  511.620520
# symphony orchestra              30         0.030272   0.000061  494.601958
# music education                 31         0.031282   0.000065  484.879014
# music teacher                   30         0.030272   0.000065  469.237755
# chamber music                   29         0.029263   0.000063  465.533247
# acoustic guitar                 28         0.028254   0.000065  437.955238
# musical instrument              63         0.063572   0.000151  422.313980
# electronic music                35         0.035318   0.000086  410.583036
#
#
# Motion Pictures and Film
# ========================
#                           topics_list  share_in_sector  share_all   share_norm
# level_1
# independent cinema                 10           0.0250   0.000025  1007.531667
# film distribution                  14           0.0350   0.000038   919.920217
# feature length                     11           0.0275   0.000036   755.648750
# feature films                      28           0.0700   0.000094   742.391754
# royal television society           11           0.0275   0.000038   722.794457
# independent film                   18           0.0450   0.000065   697.521923
# film festivals                     12           0.0300   0.000050   604.519000
# digital cinema                     14           0.0350   0.000063   556.793816
# factual entertainment              12           0.0300   0.000056   533.399118
# executive producer                 10           0.0250   0.000055   457.968939
#
#
# Museums
# =======
#                         topics_list  share_in_sector  share_all   share_norm
# level_1
# funding towards                   5         0.029240   0.000008  3535.198830
# museum development                8         0.046784   0.000017  2828.159064
# history section                   5         0.029240   0.000012  2525.142022
# art fund                          9         0.052632   0.000023  2272.627820
# history museum                    7         0.040936   0.000020  2062.199318
# scale model                       7         0.040936   0.000022  1903.568601
# natural science                   5         0.029240   0.000017  1767.599415
# science museum                    6         0.035088   0.000026  1325.699561
# independent charitable            6         0.035088   0.000026  1325.699561
# heritage site                     6         0.035088   0.000031  1116.378578
#
#
# Computer Games
# ==============
#                            topics_list  share_in_sector  share_all  \
# level_1
# games industry                      20         0.063291   0.000038
# independent game                     9         0.028481   0.000020
# closed beta                          6         0.018987   0.000013
# single player                        7         0.022152   0.000017
# game play                            7         0.022152   0.000018
# new game                            20         0.063291   0.000053
# slot games                          10         0.031646   0.000026
# game development                    16         0.050633   0.000046
# interactive entertainment           11         0.034810   0.000033
# game developer                      26         0.082278   0.000079
#
#                             share_norm
# level_1
# games industry             1663.508531
# independent game           1434.776108
# closed beta                1434.776108
# single player              1339.124367
# game play                  1217.385788
# new game                   1195.646756
# slot games                 1195.646756
# game development           1093.162749
# interactive entertainment  1052.169146
# game developer             1036.227189
#
#
# Apparel and Fashion
# ===================
#                       topics_list  share_in_sector  share_all  share_norm
# level_1
# corporate wear                 32         0.036405   0.000058  628.786218
# quality clothing               32         0.036405   0.000061  594.797774
# garment decoration             24         0.027304   0.000048  569.159939
# work wear                      27         0.030717   0.000061  501.860622
# corporate clothing             27         0.030717   0.000061  501.860622
# fashion industry               26         0.029579   0.000061  483.273191
# promotional clothing           37         0.042093   0.000088  480.116835
# wedding dress                  49         0.055745   0.000127  437.649498
# polo shirts                    29         0.032992   0.000078  424.347082
# wedding dresses                44         0.050057   0.000119  420.282455
#
#
# Animation
# =========
#                        topics_list  share_in_sector  share_all   share_norm
# level_1
# animated short                   3           0.0375   0.000007  5667.365625
# stop motion animation            2           0.0250   0.000005  5037.658333
# vanilla ice cream                2           0.0250   0.000005  5037.658333
# reading festival                 3           0.0375   0.000008  4533.892500
# character design                 3           0.0375   0.000010  3778.243750
# successful holiday               2           0.0250   0.000008  3022.595000
# animation production             5           0.0625   0.000028  2222.496324
# stop motion                      3           0.0375   0.000028  1333.497794
# live action                      5           0.0625   0.000101   619.384221
# visual effect                    5           0.0625   0.000126   497.137336
#
#
# Libraries
# =========
#                            topics_list  share_in_sector  share_all  \
# level_1
# book buying                          3         0.052632   0.000005
# library assistant                    2         0.035088   0.000003
# research libraries                   2         0.035088   0.000005
# library card                         2         0.035088   0.000005
# library policy                       2         0.035088   0.000005
# large modern                         4         0.070175   0.000012
# school library                       3         0.052632   0.000010
# local study                          3         0.052632   0.000010
# bibliographic information            2         0.035088   0.000008
# study space                          2         0.035088   0.000010
#
#                              share_norm
# level_1
# book buying                10605.596491
# library assistant          10605.596491
# research libraries          7070.397661
# library card                7070.397661
# library policy              7070.397661
# large modern                6060.340852
# school library              5302.798246
# local study                 5302.798246
# bibliographic information   4242.238596
# study space                 3535.198830
#
#
# Luxury Goods and Jewellery
# ==========================
#                    topics_list  share_in_sector  share_all  share_norm
# level_1
# wedding ring                39         0.036620   0.000068  539.934524
# engagement rings            52         0.048826   0.000091  536.662194
# diamond jewellery           41         0.038498   0.000073  528.921874
# quality jewellery           73         0.068545   0.000131  524.512831
# bespoke jewellery           48         0.045070   0.000086  523.960130
# fine jewellery              44         0.041315   0.000079  520.321518
# white gold                  32         0.030047   0.000058  518.970034
# unique jewellery            36         0.033803   0.000066  510.861127
# new jewellery               26         0.024413   0.000048  508.903804
# assay office                24         0.022535   0.000045  504.554199
#
#
# Photography
# ===========
#                         topics_list  share_in_sector  share_all  share_norm
# level_1
# event photography                28         0.036601   0.000050  737.539521
# family portrait                  25         0.032680   0.000045  731.686032
# wedding photographer             59         0.077124   0.000108  717.277446
# portrait photography             35         0.045752   0.000065  709.172616
# wedding photography              91         0.118954   0.000169  705.001012
# school photography               16         0.020915   0.000031  665.449192
# commercial photography           52         0.067974   0.000103  662.765929
# photography business             18         0.023529   0.000036  646.544385
# portrait photographer            33         0.043137   0.000074  579.495338
# photography service              49         0.064052   0.000111  577.922759
#
#
# Broadcast Media (TV, Radio)
# ===========================
#                       topics_list  share_in_sector  share_all   share_norm
# level_1
# billboard hot                  13         0.027027   0.000023  1167.025097
# community radio                40         0.083160   0.000073  1142.542053
# broadcast technology           13         0.027027   0.000026  1021.146959
# outside broadcast              30         0.062370   0.000066   942.597193
# sky digital                    13         0.027027   0.000031   859.913229
# digital radio                  15         0.031185   0.000038   819.649733
# sky news                       13         0.027027   0.000035   778.016731
# specialist music               17         0.035343   0.000046   763.054871
# commercial radio               14         0.029106   0.000045   651.672134
# television channel             12         0.024948   0.000041   603.262204
#
#
# Arts and Crafts
# ===============
#                         topics_list  share_in_sector  share_all  share_norm
# level_1
# art fairs                        25         0.027412   0.000048  571.422225
# picture framing                  37         0.040570   0.000071  570.359114
# limited edition prints           22         0.024123   0.000043  560.872891
# antique furniture                46         0.050439   0.000093  544.483748
# solo exhibitions                 27         0.029605   0.000055  542.331639
# oil painting                     50         0.054825   0.000112  487.389545
# group exhibition                 22         0.024123   0.000050  486.089839
# auction houses                   34         0.037281   0.000078  479.508352
# contemporary artists             35         0.038377   0.000083  463.994846
# art world                        25         0.027412   0.000066  414.281113

# %%
# Have a look at the detailed topics
#Extracting the info.
det_top_distr = sum_elements_in_list_of_lists(data3.topics_detailed.dropna())

# %%
#What's their distribution?
print(len(det_top_distr))
print(det_top_distr.describe())

print(det_top_distr.sum())
# Out:
# 6189570
# count    6.189570e+06
# mean     4.023699e+00
# std      2.179109e+01
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      2.000000e+00
# 75%      3.000000e+00
# max      2.130700e+04
# dtype: float64
# 24904966

# %% [markdown]
# We have 6m unique topics appearing a total of 24m times... How can we use them?

# %%
#How many are there per company? Could we use these data to do some topic modelling / other types of NLP?

comp_topic_n = pd.Series([len(x) for x in data3.topics_detailed.dropna()])

comp_topic_n.describe()

#Ok so this is quite rich. We could do something with it.
# Out:
# count    168199.000000
# mean        148.068574
# std         947.679107
# min           1.000000
# 25%           8.000000
# 50%          19.000000
# 75%          59.000000
# max      112320.000000
# dtype: float64

# %% [markdown]
# ## Postal cities

# %%
#What about the 'postal cities'?
#For how many do we have data?

#We only have addresses for ~ half of the data
np.sum(data3.postaltowns.isnull())/len(data3)
# Out:
# 0.50386359156317762

# %%
#Create list of postaltowns

data3['towns_list'] = [[t.lower() for t in x.split(',')] if type(x)==str else [] for x in data3.postaltowns]

print(pd.Series([len(x) for x in data3['towns_list']]).describe())
# Out:
# count    253650.000000
# mean          3.902168
# std         157.204638
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max       43592.000000
# dtype: float64

# %%
#There are a few companies with LOTS of addresses

data3.loc[[len(x)>500 for x in data3['towns_list']],:][:10]
# Out:
#                      name        generatedsector           generatedsubsector  \
# 375         1st Directory  Professional Services    Marketing and Advertising
# 1417            5pm.co.uk             Technology                     Internet
# 1626     96.4 Eagle Radio         Media and Arts  Broadcast Media (TV, Radio)
# 6247               Adzuna             Technology                     Internet
# 11450                Amee             Technology                     Internet
# 14461      Approved Index             Technology                     Internet
# 19790         Auto Trader         Media and Arts     Newspapers and Magazines
# 23259  The Bath Chronicle         Media and Arts     Newspapers and Magazines
# 24818     Bedford Midweek         Media and Arts     Newspapers and Magazines
# 27633                KSTE  Professional Services                       Design
#
#       generatedtag                sourcesector  \
# 375             R2       Professional Services
# 1417            R1                  Technology
# 1626            R1              Media and Arts
# 6247            R1                  Technology
# 11450           R2    Energy and Environmental
# 14461           R1                  Technology
# 19790           R1              Media and Arts
# 23259           R1              Media and Arts
# 24818           R1              Media and Arts
# 27633           R2  Supply Chain and Transport
#
#                              sourcesubsector status  \
# 375                     Information Services      U
# 1417                                Internet      U
# 1626             Broadcast Media (TV, Radio)      U
# 6247                                Internet      U
# 11450          Renewables and Sustainability      U
# 14461                               Internet      U
# 19790               Newspapers and Magazines      U
# 23259               Newspapers and Magazines      U
# 24818               Newspapers and Magazines      U
# 27633  Transportation, Trucking and Railroad      U
#
#                                          predictedsector  \
# 375    Non Profit and Education:Charities and Foundat...
# 1417   Technology:Internet:37.1080395934,Leisure and ...
# 1626   Non Profit and Education:Charities and Foundat...
# 6247   Professional Services:Staffing and Recruiting:...
# 11450  Professional Services:Information Services:25....
# 14461  Technology:Internet:28.0412671731,Professional...
# 19790  Supply Chain and Transport:Automotive:64.45716...
# 23259  Media and Arts:Newspapers and Magazines:50.812...
# 24818  Non Profit and Education:Charities and Foundat...
# 27633  Industrial and Agriculture:Packaging and Print...
#
#                                                   topics  \
# 375         united kingdom,directory listings,real world
# 1417                                                 NaN
# 1626   west surrey,rock songs,brain tumour,classic po...
# 6247                             car ads,vertical search
# 11450  waste generation,information provider,carbon e...
# 14461  valid email,time effective,enquiry form,servic...
# 19790  digital brands,automotive sector,car ownership...
# 23259  bath rugby,central library,safety group,video ...
# 24818               social media,latest news,local world
# 27633                                                NaN
#
#                                              postaltowns  \
# 375    600 096,AB10 1AQ,AB10 1AR,AB10 1TN,AB10 1XE,AB...
# 1417   AB10 1JN,AB10 1NN,AB10 1SU,AB10 1TX,AB10 6PY,A...
# 1626   BN21 4TX,BN27 4AB,CR0 1DN,CR8 2EF,EC2A 2EW,GU1...
# 6247   AB10 1JX,AB11 7XH,AB22 8AL,AL3 8HZ,AL4 9RH,AL5...
# 11450  AB10 1FW,AB10 1QR,AB11 5NS,AB21 0DP,AB21 7HG,A...
# 14461  AB10 1FW,AB10 1JG,AB15 4ZT,AB25 3TZ,AB34 5HE,A...
# 19790  AB12 3JG,AB21 9US,AB23 8JW,AB31 4HE,AB51 5RB,A...
# 23259  B74 2PG,B79 7UL,BA1 0AB,BA1 1AA,BA1 1AN,BA1 1B...
# 24818  BS1 4ND,BS34 5TA,CM1 6JN,DE73 7JW,DH4 5QY,E14 ...
# 27633  AB11 6BQ,AB11 8HU,AB11 9BD,AB11 9QQ,AB16 5PZ,A...
#
#                            website  \
# 375             1stdirectory.co.uk
# 1417                 www.5pm.co.uk
# 1626            www.964eagle.co.uk
# 6247              www.adzuna.co.uk
# 11450                 www.amee.com
# 14461      www.approvedindex.co.uk
# 19790         www.autotrader.co.uk
# 23259      www.bathchronicle.co.uk
# 24818  www.bedfordshire-news.co.uk
# 27633    www.biketransporter.co.uk
#
#                                                   desc_1  \
# 375    QualitySolicitors D'Angibau - Bournemouth are ...
# 1417         Browse menus, read reviews and pick offers.
# 1626   Eagle Radio is the number one radio station in...
# 6247   Adzuna is a search engine for job advertisemen...
# 11450  AMEE’s mission is to empower businesses to be ...
# 14461  Appletree Print's listing in the Approved Inde...
# 19790  Our make a difference strategy extends to ensu...
# 23259  The Bath Chronicle is a weekly newspaper cover...
# 24818  Bedfordshire on Sunday (BoS) is a free local n...
# 27633                                                NaN
#
#                                                   desc_2  \
# 375    Directories are the basic building blocks of c...
# 1417   For restaurateurs 5pm offer the opportunity to...
# 1626   Eagle Radio (formerly 96.4 The Eagle) is a loc...
# 6247   Adzuna is a search engine for job advertisemen...
# 11450  Avoiding Mass Extinctions Engine (abbreviated ...
# 14461  At Approved Index our unique tailored service ...
# 19790  Auto Trader Group plc is an automotive classif...
# 23259  The Bath Chronicle is a weekly newspaper, firs...
# 24818  Bedfordshire on Sunday (BoS) was a free local ...
# 27633                                                NaN
#
#                                          topics_detailed  \
# 375    [abrasive waterjet cutting, a conversation, ac...
# 1417   [aa rosette, beauty outlets, best deals, black...
# 1626   [absolute mile, absolute outrage, accident inv...
# 6247   [account management, account manager, ads site...
# 11450  [accidental loss, accounting methodologies, ai...
# 14461  [acceptable air quality, ad credits, additiona...
# 19790  [acceleration times, accountancy profession, a...
# 23259  [abbey churchyard, abbey ward, absent child, a...
# 24818  [access request, account changes, account paym...
# 27633  [destination such, first class, kingston upon ...
#
#                                              topics_list  has_topic  \
# 375     [united kingdom, directory listings, real world]       True
# 1417                                                  []      False
# 1626   [west surrey, rock songs, brain tumour, classi...       True
# 6247                          [car ads, vertical search]       True
# 11450  [waste generation, information provider, carbo...       True
# 14461  [valid email, time effective, enquiry form, se...       True
# 19790  [digital brands, automotive sector, car owners...       True
# 23259  [bath rugby, central library, safety group, vi...       True
# 24818           [social media, latest news, local world]       True
# 27633                                                 []      False
#
#                                               towns_list
# 375    [600 096, ab10 1aq, ab10 1ar, ab10 1tn, ab10 1...
# 1417   [ab10 1jn, ab10 1nn, ab10 1su, ab10 1tx, ab10 ...
# 1626   [bn21 4tx, bn27 4ab, cr0 1dn, cr8 2ef, ec2a 2e...
# 6247   [ab10 1jx, ab11 7xh, ab22 8al, al3 8hz, al4 9r...
# 11450  [ab10 1fw, ab10 1qr, ab11 5ns, ab21 0dp, ab21 ...
# 14461  [ab10 1fw, ab10 1jg, ab15 4zt, ab25 3tz, ab34 ...
# 19790  [ab12 3jg, ab21 9us, ab23 8jw, ab31 4he, ab51 ...
# 23259  [b74 2pg, b79 7ul, ba1 0ab, ba1 1aa, ba1 1an, ...
# 24818  [bs1 4nd, bs34 5ta, cm1 6jn, de73 7jw, dh4 5qy...
# 27633  [ab11 6bq, ab11 8hu, ab11 9bd, ab11 9qq, ab16 ...

# %% [markdown]
# This seems to be picking up losts of directories / newspapapers / online sites for mapping (?)

# %%
#What are the most popular towns?

pd.Series([x for el in data3['towns_list'] for x in el]).value_counts(ascending=False)[:10]
# Out:
# ip14 1dt    3476
# ec1v 2nx     410
# ec2a 4ne     386
# n1 7gu       386
# w14 8ux      290
# wc2h 9jq     284
# w1b 3hh      275
# e1 6ql       246
# ec1v 4pw     244
# e16 1xl      242
# dtype: int64

# %%
data3.columns
# Out:
# Index(['name', 'generatedsector', 'generatedsubsector', 'generatedtag',
#        'sourcesector', 'sourcesubsector', 'status', 'predictedsector',
#        'topics', 'postaltowns', 'website', 'desc_1', 'desc_2',
#        'topics_detailed', 'topics_list', 'has_topic', 'towns_list'],
#       dtype='object')

# %%
#Rename columns
data3.columns = ['name','creative_glai_sector','creative_glai_subsector','source',
                'source_glai_sector','source_glai_subsector','status','sector_probabilities','topics_short','postcodes',
               'website','topics_list','description_1','description_2','long_topics','has_topics','postcode_list']

#Drop irrelevant columns3
glass_ai = data3.drop(['status','topics_short','postcodes','has_topics'],axis=1)

# %%
del data2, data3, topics

# %%
glass_ai.rename(columns={'description2':'description_2'},inplace=True)

# %%
#Output for Cath
glass_ai.reset_index(drop=False).to_json(int_data+'/{date}_glai_companies.json'.format(date=today_str),orient='records')

# %%
check_ids = [139, 268, 413, 2714518, 2714660, 2715063]

[x in glass_ai.reset_index(drop=False)['index'] for x in check_ids]
# Out:
# [True, True, True, False, False, False]

# %%
#ARGH

#for x in glass_ai.columns:
#    print(x+" ("+
#          re.sub("\'","",re.sub(">",")",
#                 re.sub("<","(",str(type(glass_ai.loc[:,x].iloc[0])))).split(" ")[1]+":"))
#    print("\n")

# %% [markdown]
# ## 2. Explore and enrich data
#
# * Rename and document data
# * Decide what to do about companies with mixed sectors
# * Obtain postcodes and assign companies to a single location
# * Develop a protocol to assign companies to sectors and validate vs official data
#  * Use the lookup. Challenge = There are a couple of sectors with more than one

# %%
#Load metadata for all this enrichment

#Load NSPL data
nspl = pd.read_csv(ext_data+'/NSPL_AUG_2017_UK/Data/NSPL_AUG_2017_UK.csv',
                   usecols=['pcds','ttwa','laua','gor']
                  )
#Load TTWA labels
ttwa_labels = pd.read_csv(ext_data+'/NSPL_AUG_2017_UK/Documents/TTWA names and codes UK as at 12_11 v5.txt',
                          delimiter='\t')
#Tidy labels
ttwa_labels.rename(columns={'TTWA11CD':'ttwa_code','TTWA11NM':'ttwa_name'},inplace=True)


#Load the GlassAI - DCMS lookup and lowercase columns
glai_dcms_lookup = pd.read_excel(ext_data+'/glass_ai_dcms_lookup.xlsx',sheetname=1)
glai_dcms_lookup.columns = [x.lower() for x in glai_dcms_lookup.columns]

glai_dcms_lookup.rename(columns={'creative_sector':'dcms_sector'},inplace=True)
# Out:
# /usr/local/lib/python3.5/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
#We want to create a dict looking up subsectors vs dcms
#First focus on the subsectors linked to dcms sectors
glai_dcms_lookup_subset = glai_dcms_lookup.dropna(axis=0,subset=['dcms_sector'])

#This is a dict with keys = glai subsector labels and values = dcms sectors
glai_subsector_dcms_lookup = {x:y for x,y in zip(glai_dcms_lookup_subset.subsector,
                                                 glai_dcms_lookup_subset.dcms_sector)}

#This is a list of all the glai labels associated to a creative subsector
glai_creative_subsector_labels = list(glai_subsector_dcms_lookup.keys())

# %%
#Drop companies with lots of postcodes
postcodes_n = pd.Series([len(x) for x in glass_ai.postcode_list])

postcodes_n.value_counts()/len(postcodes_n)

#If we drop all companies with more than 5 postcodes this amounts to 4% of the data.

100*np.sum(postcodes_n>5)/len(postcodes_n)

#Subset the data to focus on companies with few addresses, and identify the top address
#NB need to reindex
glass_ai_sub = glass_ai.reset_index(drop=False)[postcodes_n<=5]

#Here is the top address
glass_ai_sub['postcode_top'] = [x[0].strip() if len(x)>0 else np.nan for x in glass_ai_sub.postcode_list]

#Merge with nspl
nspl['pcds']=[x.lower() for x in nspl['pcds']]

# %%
#There is a small number of missing postcodes from the NSPL data
#Some of them seem postboxes
missing_postcodes = set(glass_ai_sub['postcode_top'].dropna()) - set(nspl['pcds'])

np.sum([x[0] in digits for x in missing_postcodes])
# Out:
# 261

# %%
#Let's work with these
#Merge
glass_ai_sub = pd.merge(pd.merge(glass_ai_sub,nspl,left_on='postcode_top',right_on='pcds',how='left'),
                       ttwa_labels,left_on='ttwa',right_on='ttwa_code')
                       
#Now get the sectors
glai_labelled = pd.merge(glass_ai_sub,
                        glai_dcms_lookup,left_on='creative_glai_subsector',right_on='subsector')

#This variable captures if the glass ai subsector was a creative subsector
glai_labelled['has_top_subsector'] = [x==y for x,y in zip(glai_labelled.creative_glai_subsector,
                                                          glai_labelled.source_glai_subsector)]

# %%
glai_labelled.drop('observation',axis=1,inplace=True)

# %% [markdown]
# Now we want to explore different ways to define a creative sector
#
# * We can use GlassAI's strategy or we can find what's the top sector and probability for each company and create some rules (ie if the top sector is creative and with a probability above a certain threshold...)

# %%
#We neeed to create an alternative sector probabilities variable removing commas (commas also used to separate
#sectors in the sector probability variable)

glai_labelled['sector_probs_clean'] = [re.sub(", "," " ,x) 
                                    if type(x)==str else np.nan for x in glai_labelled.sector_probabilities]

#GLAI probabilities is a list where every element is a list of subsectors and probabilities
glai_probabilities = [
    [[el.split(':')[1],float(el.split(':')[2])] for el in x.split(",")] 
    if type(x)==str else np.nan for x in glai_labelled['sector_probs_clean']]

# %%
#What are the categories I want to analyse?

#First creative sector (with a prob threshold)

def get_first_creative_sector(prob_vector,thres=30):
    '''
    This function goes through a vector of sector probabilities and returns a creative sector if it is the first one
    and above a certain probability threshold
    '''
    
    #If the vector of probabilities isn't a missing value...
    if type(prob_vector)==float:
        return(np.nan)
    else:
        most_prob = sorted(prob_vector,key=lambda x:x[1],reverse=True)[0]
        if most_prob[0] in glai_creative_subsector_labels and most_prob[1]>thres:
            return(glai_subsector_dcms_lookup[most_prob[0]])
        else:
            return(np.nan)
    
#Other creative sectors (with a probability threshold)


def get_top_creative_sector(prob_vector,thres=10):
    '''
    This function goes through a vector of sector probabilities and returns the top creative sector if it is
    above a threshold
    '''
    
    #If the vector of probabilities is a missing value then we get a missing value
    if type(prob_vector)==float:
        return(np.nan)
    else:
        #Sort the creative subsectors present here
        most_prob_creative = sorted([x for x in prob_vector if x[0] in glai_creative_subsector_labels],
                                  key = lambda x:x[1],reverse=True)
        
        #If there were no creative subsectors in the topic mix
        if len(most_prob_creative)==0:
            
            return(np.nan)
        
        else:
        #If there were some creative subsectors but the probability of the top one was below the threshold...
        
            if most_prob_creative[0][1]<thres:
                
                return(np.nan)
            
            else:
                return(glai_subsector_dcms_lookup[most_prob_creative[0][0]])

# %%
#Now we create two variables capturing if a company is the top cr

glai_labelled['creative_sector_first'] = pd.Series([get_first_creative_sector(x,20) for x in glai_probabilities])

glai_labelled['creative_sector_top']= creative_sector_is_present = pd.Series([get_top_creative_sector(x,10) for x in glai_probabilities])


#And finally we create a variable that captures what's the top creative sector ONLY if this isn't the first.
#It's almost like a creative economy measure
glai_labelled['creative_sector_not_first'] = [y if type(x)==float else np.nan for x,y in
                                             zip(glai_labelled.creative_sector_first,
                                                 glai_labelled.creative_sector_top)]

# %% [markdown]
# Now we have a couple of variables we can use for comparisons with the official IDBR data.
#
# Next stages:
#
# * Compare creative GLAI LQ vs non creative
# * Produce some descriptive stats

# %%
#First 

fig,ax = plt.subplots(ncols=2,figsize=(15,5),sharey=True)


pd.crosstab(glai_labelled.creative_sector_first,glai_labelled.source).plot.bar(
    stacked=False,ax=ax[0],title='Creative first')
pd.crosstab(glai_labelled.creative_sector_not_first,glai_labelled.source).plot.bar(
    stacked=False,ax=ax[1],title='Creative presence')

#Unsurprisingly, most creative companies are picked up by the R1 source, while
#creative economy businesses are picked up by R2

# %%
#What do we have in total?
#Creative sector first
creative_sector_first = glai_labelled.creative_sector_first.value_counts()

print(creative_sector_first)

print('')
print(creative_sector_first.sum())

print('')

creative_sector_present = glai_labelled.creative_sector_not_first.value_counts()

print('')

print(creative_sector_present)

print('')
print(creative_sector_present.sum())
# Out:
# it_software               16806
# advertising_marketing     10175
# design                     5063
# video_film_photography     3686
# music_performing_arts      3118
# architecture               2982
# publishing                 2141
# crafts                     1598
# libraries_museums             7
# Name: creative_sector_first, dtype: int64
#
# 45576
#
#
# it_software               15377
# advertising_marketing      6318
# design                     5526
# music_performing_arts      4877
# video_film_photography     3823
# publishing                 2996
# architecture               1994
# crafts                     1868
# libraries_museums            23
# Name: creative_sector_not_first, dtype: int64
#
# 42802

# %% [markdown]
# So we end with around 90K companies

# %%
def extract_companies_in_sector(sector,variable,n=5):
    '''
    Extracts some companies from a sector for visual inspection
    
    '''
    #Select the sector in the variable
    out = glai_labelled.loc[glai_labelled[variable]==sector,:].reset_index(drop=False)
    
    #print(out)
    indices_to_extract = np.random.randint(0,len(out),size=n)
    
    return(out.loc[indices_to_extract,['name','topics_list','long_topics','description_1','description_2']])

# %%
design_comps = extract_companies_in_sector('advertising_marketing','creative_sector_not_first',n=10)

# %%
design_comps
# Out:
#                       name                                        topics_list  \
# 8007         Sketch Events  We are Sketch: the experiential and pr stunt e...
# 428                BluZinc  Career opportunity in Durban, South Africa for...
# 5461           GLOBE LOCAL                                                NaN
# 3345  Montenegro Prospects  Montenegro Prospects is the most experienced I...
# 7843    Ace Communications                                                NaN
# 868          Wait And Read                                                NaN
# 4175           Supermarket  Supermarket.co.uk was founded in 1996, back wh...
# 6006      HOWSE ASSOCIATES                                                NaN
# 6703      Business Network                                                NaN
# 1395           GERMAN YWCA                                                NaN
#
#                                             long_topics  \
# 8007                                [brand ambassadors]
# 428             [outstanding career, breakfast meeting]
# 5461                                                 []
# 3345  [dance festival, year residency, property buye...
# 7843                                                 []
# 868                                                  []
# 4175  [greater incentive, food prices, financial bur...
# 6006                                 [property related]
# 6703                                  [business person]
# 1395                              [visitor attractions]
#
#                                           description_1  \
# 8007  We are Sketch: the experiential and PR stunt e...
# 428   BluZinc candidate attraction provides permanen...
# 5461  Globe Local Electronics has designed a ‘Five P...
# 3345  Please note that each holiday lasts two days, ...
# 7843                                                NaN
# 868                                                 NaN
# 4175  Supermarket.co.uk was founded in 1996, back wh...
# 6006  We pride ourselves on providing our clients wi...
# 6703  We have been operating our unique Business Net...
# 1395                                                NaN
#
#                                           description_2
# 8007  [actual chocolate, actual eclipse, adrenaline-...
# 428   [admired brands, advert copy, advertised compe...
# 5461                   [best customer service possible]
# 3345  [accession talks, actual area, administrative ...
# 7843                                                NaN
# 868                                                 NaN
# 4175  [afternoon trading, annual sales increase, ave...
# 6006  [best possible service, chartered surveyor, co...
# 6703  [business network, comfortable business, great...
# 1395                         [free visitor attractions]

# %% [markdown]
# ## Some benchmarking

# %%
#Sector totals (all observations)
glass_ai_sector_totals = glai_labelled.dcms_sector.value_counts()
glass_ai_sector_totals.name = 'glass_ai_creative_all'

#Sector totals (high q observations)
glass_ai_sector_totals_high_q = glai_labelled.loc[glai_labelled.source=='R1','dcms_sector'].value_counts()
glass_ai_sector_totals_high_q.name = 'glass_ai_creative_r1'

#sector totals (perfect matches)
glass_ai_sector_totals_perf_match = glai_labelled.loc[
    glai_labelled.has_top_subsector==True,'dcms_sector'].value_counts()

glass_ai_sector_totals_perf_match.name = 'glass_ai_creative_top_match'

#Sector (totals based on first matches and high prob thresholds)
glai_creative_industries_first_totals = creative_sector_first
glai_creative_industries_first_totals.name= 'glass_ai_creative_top_high'

#Creative economy (totals based on top matches and high prob thresholds)
glai_creative_industries_present_totals = creative_sector_present
glai_creative_industries_present_totals.name= 'glass_ai_creative_present_high'

# %%
#Let's do a comparison with the IDBR data

#First, create a name lookup so we can merge easily

dcms_names_lookup = {
    'IT, software and computer services':'it_software',
    'Music, performing and visual arts':'music_performing_arts',
    'Film, TV, video, radio and photography':'video_film_photography',
    'Advertising and marketing':'advertising_marketing',
    'Design':'design',
    'Architecture':'architecture',
    'Publishing':'publishing',
    'Museums, galleries and libraries':'libraries_museums',
    'Crafts':'crafts',
    'not_in_sector':'not_in_sector',
    'creative_industries':'creative_industries'}

# %%
#Load totals
off_stats =pd.read_csv(ext_data+'/26_11_2017_processed_data.csv')


idbr_totals = off_stats[['sector','bc_2016','ttwa_name','ttwa_code']]

# %%
#Extract totals (with clean mname)
idbr_totals['sector_clean'] = [dcms_names_lookup[x] for x in idbr_totals.sector]
idbr_totals.set_index('sector_clean',inplace=True)
#idbr_totals_2016 = idbr_totals.loc[
#    idbr_totals.year==2016,:].groupby('sector_clean')['value'].sum().sort_values(ascending=False)
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
idbr_glass_ai = pd.concat([idbr_totals.reset_index(drop=False).groupby(
    'sector_clean')['bc_2016'].sum(),
                           glass_ai_sector_totals,glass_ai_sector_totals_high_q,
                           glai_creative_industries_first_totals,glai_creative_industries_present_totals,
                          glass_ai_sector_totals_perf_match],axis=1)

idbr_glass_ai['glass_ai_coverage_all'] = idbr_glass_ai['glass_ai_creative_all']/idbr_glass_ai['bc_2016']
idbr_glass_ai['glass_ai_coverage_r1'] = idbr_glass_ai['glass_ai_creative_r1']/idbr_glass_ai['bc_2016']
idbr_glass_ai['glass_ai_coverage_p'] = idbr_glass_ai['glass_ai_creative_top_match']/idbr_glass_ai['bc_2016']
idbr_glass_ai['glass_ai_coverage_first'] = idbr_glass_ai['glass_ai_creative_top_match']/idbr_glass_ai['bc_2016']
idbr_glass_ai['glass_ai_r1_ratio'] = idbr_glass_ai['glass_ai_creative_r1']/idbr_glass_ai['glass_ai_creative_all']

idbr_glass_ai.dropna(inplace=True)

# %%
#Visualise differences in rankings

fig,ax = plt.subplots(figsize=(10,5))

#This is giving us the rank of each sector in each dataset
data_ranked = [idbr_glass_ai[x].rank() for x in ['bc_2016','glass_ai_creative_top_high']]

#This list contains sector names for plotting
var_names = idbr_glass_ai.index

#Create scatter
ax.scatter(data_ranked[0],data_ranked[1])


#Add text labels to points
for num,val in enumerate(np.arange(len(var_names))):
    ax.annotate(var_names[num],(data_ranked[0][num]+0.1,data_ranked[1][num]))

#Add a 1-1 line
ax.plot(np.arange(len(var_names)),np.arange(len(var_names)),linestyle='dashed')
    
#Add titles
ax.set_title('Comparison between Glass AI and DCMS totals by sector')
ax.set_xlabel('DCMS ranking (2016)')
ax.set_ylabel('Glass AI ranking (current)')
# Out:
# Text(0,0.5,'Glass AI ranking (current)')

# %% [markdown]
# Glass AI data seems to have better coverage of B2B businesses like advertising and design

# %%
#In order to create the LQs for Glass AI we need to capture activity in all other sectors

glass_all = pd.read_csv(ext_data+'/org_non_creative_ttwa.txt',delimiter='\t',header=None)
glass_all.columns = ['ttwa_code','glass_sector','glass_subsector','business_count']

print(glass_all.business_count.sum())

#Create totals. Oddly, the totals are quite small

#We create a list of non-creative sectors by TTWA and label to concatenate along rows.
glass_ttwa_totals = glass_all.groupby('ttwa_code')['business_count'].sum().reset_index(drop=False)
glass_ttwa_totals['sector']='non_creative'
# Out:
# 276508

# %%
#Create a couple of validation functions
def generate_spec_lq(df,filter_variable=None,filter_value=None,spec_name='unfiltered_lq'):
    '''
    This function generates a specialisation DF based on different filters 
    #(we use those with Glass AI data to validate vs IDBR)
    '''
    
    if filter_variable!=None:
        df = df.loc[df[filter_variable]==filter_value,:]
    
    #Group
    df_grouped = df.groupby(
            ['ttwa_code','dcms_sector']).size().reset_index(drop=False)
    df_grouped.rename(columns={0:'business_count','dcms_sector':'sector'},inplace=True)
        
        
    #Then we merge on TTWAs with the glass_ttwa_totals
    all_sectors_ttwa = pd.concat([df_grouped,glass_ttwa_totals],axis=0)
    
    
    #Create LQs by sector (inside the CIs)
    df_lq = create_lq_df(pd.pivot_table(all_sectors_ttwa,index='ttwa_code',columns='sector',
                                     values='business_count',aggfunc='sum').fillna(value=0))

    #Melt for merging later
    df_spec = pd.melt(df_lq.reset_index(drop=False),
                                 id_vars='ttwa_code',value_name=spec_name).set_index(['ttwa_code','sector'])
    
    return(df_spec)
 

def get_validation_charts(df,var_1,var_2,ax,col,name=None):
    '''
    This function creates a set of figures of the relationship between two variables,
    one of which will be the GlassAI data we want to validate.
    
    '''
    
    for num,x in enumerate(sorted(set(spec_comparison.sector))):
        data = df.loc[df.sector==x,:]

        cor = np.round(data.loc[:,[var_1,var_2]].apply(lambda x: np.log(x),axis=1).corr('spearman').iloc[0,1],2)


        ax[num][col].scatter(np.log(data[var_1]),np.log(data[var_2]),alpha=0.8)
        ax[num][col].set_title('Specialisation comparison for \n {sector} \n corr={cor}'.format(
            sector=x,cor=cor))
        ax[num][col].set_xlabel(var_1)
        ax[num][col].set_ylabel(var_2)

# %%
#Produce spec metrics


#Ok, we need to add a couple of filter variables to deal with the new ones we have created
glai_labelled['is_creative_high_thres'] = [type(x)!=float for x in glai_labelled.creative_sector_first]
glai_labelled['is_creative_econ_high_thres'] = [type(x)!=float for x in glai_labelled.creative_sector_not_first]



glass_ai_spec_all = generate_spec_lq(glai_labelled)
glass_ai_spec_r1 = generate_spec_lq(glai_labelled,filter_variable='source',filter_value='R1',spec_name='r1_lq')
glass_ai_spec_match = generate_spec_lq(glai_labelled,filter_variable='has_top_subsector',filter_value=True,
                                      spec_name='top_match_lq')
glass_ai_spec_top_thres = generate_spec_lq(glai_labelled,filter_variable='is_creative_high_thres',filter_value=True,
                                      spec_name='high_match_lq')

glass_ai_spec_pres_thres = generate_spec_lq(glai_labelled,filter_variable='is_creative_econ_high_thres',filter_value=True,
                                      spec_name='pres_match_lq')


#Concatenate results
glass_ai_results = pd.concat([glass_ai_spec_all,glass_ai_spec_r1,glass_ai_spec_match,
                             glass_ai_spec_top_thres,
                              glass_ai_spec_pres_thres
                             ],axis=1).reset_index(drop=False)
glass_ai_results.loc[:,['lq' in x for x in glass_ai_results.columns]].corr()
# Out:
#                unfiltered_lq     r1_lq  top_match_lq  high_match_lq  \
# unfiltered_lq       1.000000  0.754445      0.621816       0.371290
# r1_lq               0.754445  1.000000      0.928191       0.686731
# top_match_lq        0.621816  0.928191      1.000000       0.811105
# high_match_lq       0.371290  0.686731      0.811105       1.000000
# pres_match_lq       0.295547  0.202138      0.164960       0.182402
#
#                pres_match_lq
# unfiltered_lq       0.295547
# r1_lq               0.202138
# top_match_lq        0.164960
# high_match_lq       0.182402
# pres_match_lq       1.000000

# %%
#Generate IDBR specialisation profile
idbr_totals.reset_index(drop=False,inplace=True)


idbr_vars = [x for x in set(idbr_totals.sector_clean) if x in set(glai_labelled.dcms_sector)]

idbr_total_lq = create_lq_df(pd.pivot_table(idbr_totals.loc[
    [x in idbr_vars for x in idbr_totals.sector_clean],].groupby(
    ['ttwa_code','sector_clean'])['bc_2016'].sum().reset_index(drop=False),index='ttwa_code',columns='sector_clean',
                                   values='bc_2016',aggfunc='sum'))

idbr_creative_spec = pd.melt(idbr_total_lq.reset_index(drop=False),
                            id_vars='ttwa_code',value_name='idbr_lq')

#Merge on ttwa-name and sector clean
spec_comparison = pd.merge(glass_ai_results,idbr_creative_spec,
                          left_on=['ttwa_code','sector'],right_on=['ttwa_code','sector_clean']).dropna()

# %%
#Let's plot by sector

#Create a bunch of axes
fig,ax = plt.subplots(nrows=len(set(spec_comparison.sector)),ncols=5,
                     figsize=(15,20))

get_validation_charts(spec_comparison,'idbr_lq','unfiltered_lq',ax,col=0)
get_validation_charts(spec_comparison,'idbr_lq','r1_lq',ax,col=1)
get_validation_charts(spec_comparison,'idbr_lq','top_match_lq',ax,col=2)
get_validation_charts(spec_comparison,'idbr_lq','high_match_lq',ax,col=3)
get_validation_charts(spec_comparison,'idbr_lq','pres_match_lq',ax,col=4)

plt.tight_layout()
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:42: RuntimeWarning: divide by zero encountered in log
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:45: RuntimeWarning: divide by zero encountered in log

# %% [markdown]
# Filtering affects the quality of the GlassAI match in different ways - although in general it improves it,
# with the exception of IT. NB big improvement in advertising, perhaps because the topics are picking up other sectors?

# %%
#Visualise correlation between glass AI specialisation and glass AI creative economy specialisation

glai_first_econ_lq = pd.concat([glass_ai_spec_top_thres,glass_ai_spec_pres_thres,
                                idbr_creative_spec.set_index(['ttwa_code','sector_clean'])],axis=1).reset_index(drop=False)

glai_first_econ_lq.rename(columns={'level0':'ttwa_code','level_1':'sector'},inplace=True)

fig,ax = plt.subplots(nrows=len(set(glai_first_econ_lq.sector)),figsize=(5,20))

for num,x in enumerate(set(glai_first_econ_lq.sector)):
    data = glai_first_econ_lq.loc[glai_first_econ_lq.sector==x,:]
    
    #print(data.head())
    corr = data[['high_match_lq','pres_match_lq']].corr('spearman').iloc[0,1]
    #print(corr)
    
    ax[num].scatter(data.high_match_lq,data.pres_match_lq)
    ax[num].set_title(x+" "+str(np.round(corr,2)))
    

plt.tight_layout()

# %%
#Interestingly, the best correlation is for Museums, which was identified based on topics. 
#Could we do something similar for other sectors?

#Next steps

#Redo the analysis but classifying businesses into sectors based on their top variable#
#Identify the top labels inside each sector

# %%
def get_distinctive_topics(df):
    '''
    This function gets distinctive topics in sectors. We can subset them in different ways 
    
    '''
    
    distinctive_topics_in_sector=[]

    top_keywords_by_sector = df.groupby('dcms_sector')['topics_list'].apply(
        lambda x: pd.Series([t for el in x for t in el]).value_counts(ascending=False)).reset_index(drop=False)

    for x in set(top_keywords_by_sector.dcms_sector):
        print(x)
        print('='*len(x))
    
        topics_in_sector = top_keywords_by_sector.loc[
            top_keywords_by_sector.dcms_sector==x,[
                'level_1','topics_list']].set_index('level_1').sort_values('topics_list',ascending=False)[:50]


        topics_in_sector['share_in_sector'] = topics_in_sector/topics_in_sector.sum()

        topics_in_sector_norm = topics_in_sector.join(all_topics_share)

        topics_in_sector_norm['share_norm'] = topics_in_sector_norm['share_in_sector']/topics_in_sector_norm['share_all']

        print(topics_in_sector_norm.sort_values('share_norm',ascending=False)[:10])
        
        print('\n')

    distinctive_topics_in_sector.append(
        [x,topics_in_sector_norm.sort_values('share_norm',ascending=False)[:50]])
    
    
    return(distinctive_topics_in_sector)

# %% [markdown]
# Some exploration of topics suggests that R1 / Top match pick up specialist creative businesses, while the rest
# pick up peripheral ('creative economy'?) companies. We can generate counts by sector.
#
# The two tables below show % of 'sector capabilities' in other sectors.

# %%
creative_economy_matrix_r1 = pd.crosstab(glai_labelled.loc[glai_labelled.source!='R1','source_glai_sector'],
                                      glai_labelled.loc[glai_labelled.source!='R1','dcms_sector'],
                                     normalize=0)
100*creative_economy_matrix_r1
# Out:
# dcms_sector                   advertising_marketing  architecture     crafts  \
# source_glai_sector
# Consumer Goods and Services               19.209040      2.259887  13.135593
# Energy and Environmental                  10.380623     17.647059   0.346021
# Financial Services                        20.114943      1.436782   3.735632
# Government                                33.898305      0.000000   0.000000
# Healthcare and Scientific                 22.608696      2.173913   0.869565
# Industrial and Agriculture                22.262774      1.824818   2.919708
# Leisure and Hospitality                   30.592105      1.973684   1.809211
# Non Profit and Education                  24.618321      0.954198   0.572519
# Professional Services                     28.268551      3.798587   0.706714
# Real Estate and Construction               8.792651     37.664042   1.049869
# Supply Chain and Transport                19.555556      0.888889   1.333333
# Technology                                 5.602923      0.000000   0.243605
#
# dcms_sector                      design  it_software  music_performing_arts  \
# source_glai_sector
# Consumer Goods and Services   26.553672    22.316384              10.310734
# Energy and Environmental       9.688581    54.671280               1.384083
# Financial Services             2.298851    64.080460               2.011494
# Government                     3.389831    44.067797               3.389831
# Healthcare and Scientific      9.565217    53.043478               3.478261
# Industrial and Agriculture    25.182482    36.861314               2.737226
# Leisure and Hospitality       10.855263    26.480263               9.046053
# Non Profit and Education       4.389313    38.167939               9.923664
# Professional Services          3.445230    57.950530               1.325088
# Real Estate and Construction  20.603675    25.853018               1.837270
# Supply Chain and Transport     8.444444    56.888889               3.555556
# Technology                     0.974421    89.890378               0.365408
#
# dcms_sector                   publishing  video_film_photography
# source_glai_sector
# Consumer Goods and Services     3.248588                2.966102
# Energy and Environmental        3.114187                2.768166
# Financial Services              2.873563                3.448276
# Government                     10.169492                5.084746
# Healthcare and Scientific       4.782609                3.478261
# Industrial and Agriculture      3.284672                4.927007
# Leisure and Hospitality         5.098684               14.144737
# Non Profit and Education       12.404580                8.969466
# Professional Services           2.915194                1.590106
# Real Estate and Construction    1.049869                3.149606
# Supply Chain and Transport      4.444444                4.888889
# Technology                      0.852619                2.070646

# %%
creative_economy_matrix_pm = pd.crosstab(glai_labelled.loc[glai_labelled.has_top_subsector==False,'source_glai_sector'],
                                      glai_labelled.loc[glai_labelled.has_top_subsector==False,'dcms_sector'],
                                     normalize=1)
100*creative_economy_matrix_pm
# Out:
# dcms_sector                   advertising_marketing  architecture     crafts  \
# source_glai_sector
# Consumer Goods and Services                 10.3750      3.619048  65.887850
# Energy and Environmental                     2.1875     12.761905   0.467290
# Financial Services                           5.7500      0.952381   7.009346
# Government                                   1.3750      0.000000   0.000000
# Healthcare and Scientific                    4.0625      0.952381   0.934579
# Industrial and Agriculture                  10.0625      1.904762   7.943925
# Leisure and Hospitality                     16.4375      2.857143   5.607477
# Non Profit and Education                    10.9375      1.714286   1.401869
# Professional Services                       26.0000      9.904762   3.738318
# Real Estate and Construction                 5.1875     64.380952   4.672897
# Supply Chain and Transport                   3.6250      0.761905   1.401869
# Technology                                   4.0000      0.190476   0.934579
#
# dcms_sector                      design  it_software  music_performing_arts  \
# source_glai_sector
# Consumer Goods and Services   26.219512     5.208333              29.729730
# Energy and Environmental       3.780488     5.153509               1.351351
# Financial Services             1.219512     7.483553               2.702703
# Government                     0.243902     0.767544               1.013514
# Healthcare and Scientific      2.804878     3.755482               2.702703
# Industrial and Agriculture    20.000000     6.688596               5.405405
# Leisure and Hospitality        8.902439     5.372807              21.959459
# Non Profit and Education       3.780488     6.441886              19.594595
# Professional Services          6.951220    22.368421               5.405405
# Real Estate and Construction  21.829268     6.551535               6.081081
# Supply Chain and Transport     3.048780     4.029605               3.040541
# Technology                     1.219512    26.178728               1.013514
#
# dcms_sector                   publishing  video_film_photography
# source_glai_sector
# Consumer Goods and Services     9.854015                7.716049
# Energy and Environmental        4.014599                2.469136
# Financial Services              4.379562                4.012346
# Government                      2.554745                0.925926
# Healthcare and Scientific       5.474453                3.086420
# Industrial and Agriculture      7.299270               10.185185
# Leisure and Hospitality        14.233577               32.716049
# Non Profit and Education       27.007299               15.123457
# Professional Services          15.328467                6.172840
# Real Estate and Construction    2.919708                8.024691
# Supply Chain and Transport      4.379562                4.012346
# Technology                      2.554745                5.555556

# %%
# Create this by TTWA

business_type_location = glai_labelled.groupby(['ttwa_name','ttwa_code'])['has_top_subsector'].value_counts()
business_type_location.name = 'value'
business_type_location = business_type_location.reset_index(drop=False)

business_type_location_long = pd.pivot_table(business_type_location,index=['ttwa_code','ttwa_name'],columns='has_top_subsector',values='value')

business_type_location_long['ci_spec'] = business_type_location_long[True]/business_type_location_long[False]

#data_labelled.groupby('ttwa').apply(lambda x: x.loc[x.source=='R1',:])

#business_type_location_long.loc[top_clusters,:].sort_values('ci_spec',ascending=False)[:30]

# %% [markdown]
# The above suggests that many of the more specialised, traditional creative clusters, have a stronger presence
# of 'core' creative businesses whereas other areas have more 'periphery' ones. We need additional data from GlassAI to normalise these numbers.

# %%
glass_ai_creative_totals = pd.merge(business_type_location_long.reset_index(drop=False),
                          glass_ttwa_totals.drop('sector',axis=1),left_on='ttwa_code',right_on='ttwa_code')

# %%
glass_ai_creative_totals.rename(columns={False:'creative_econ',
                                        True:'creative_industries'},inplace=True)

# %%
glass_ai_creative_totals['all_firms'] = glass_ai_creative_totals[['creative_econ','creative_industries','business_count']].sum(axis=1)

glass_ai_creative_totals['ci_share'],glass_ai_creative_totals['ce_share'] = [glass_ai_creative_totals[x]/
                                                     glass_ai_creative_totals['all_firms'] for x in ['creative_industries','creative_econ']]

glass_ai_creative_totals['ce_intensity'] = glass_ai_creative_totals['creative_econ']/(
    glass_ai_creative_totals['business_count']+glass_ai_creative_totals['creative_econ'])

# %% [markdown]
# ## Creative economy analysis
#
# We want a function that, for each TTWA, outputs a df with:
#
# * Share of CE in total by Glass AI sector
# * Share of Ce capability in total by Glass AI sector
#
# Do it as a function that loops over ttwa names?

# %%
#UK creative economy activity totals
#Focus on R2 matches
national_ce = glai_labelled.loc[[type(x)!=float for x in glai_labelled.creative_sector_not_first=='R2'],:]


national_creative_mix= pd.melt(
    pd.crosstab(national_ce.source_glai_sector,national_ce.creative_sector_not_first).reset_index(drop=False),
    id_vars='source_glai_sector')

#UK non-creative totals

national_non_ce = glass_all.groupby('glass_sector').sum()

#Merge with UK

national_creative_mix = pd.merge(national_creative_mix,national_non_ce.reset_index(drop=False),
                                left_on='source_glai_sector',right_on='glass_sector')

national_creative_mix['share'] = national_creative_mix['value']/(
    national_creative_mix['value']+national_creative_mix['business_count'])

# %%
#Mixing matrix (shows share of creative companies in each sector)


national_mix_matrix = pd.pivot_table(national_creative_mix,
                                    index='creative_sector_not_first',columns='glass_sector',values='share')

#Order Y axis and X axis
creative_embeddedness_cr_ranking = national_mix_matrix.rank(axis=0).mean(axis=1).sort_values(ascending=False).index
creative_embeddedness_non_cr_ranking = national_mix_matrix.rank(axis=1).mean().sort_values(ascending=False).index

#Plot
fig,ax = plt.subplots(figsize=(12,7))

#Here we are sorting by the ranking indices above
im = ax.imshow(national_mix_matrix.rank(axis=0).loc[creative_embeddedness_cr_ranking
                                                ,creative_embeddedness_non_cr_ranking],cmap='coolwarm',
              aspect='auto')

#Add ticks
ax.set_yticks(np.arange(len(creative_embeddedness_cr_ranking)))
ax.set_yticklabels({x:y for y,x in dcms_names_lookup.items()}[x] for x in creative_embeddedness_cr_ranking)

ax.set_xticks(np.arange(len(creative_embeddedness_non_cr_ranking)))
ax.set_xticklabels(creative_embeddedness_non_cr_ranking,rotation=90)

#Grid
ax.set_yticks([x -0.5 for x in np.arange(len(creative_embeddedness_cr_ranking))],minor=True)
ax.set_xticks([x-0.5 for x in np.arange(len(creative_embeddedness_non_cr_ranking))],minor=True)
ax.grid(which='minor',color='white',linestyle='-',linewidth=1)

ax.set_title('Levels of creative capability embeddedness in non-creative sector')

fig.colorbar(im,label='Creative embeddedness ranking')

plt.tight_layout()

plt.savefig(fig_path+'/{date_today}_creat_embeddedness_sector.pdf'.format(date_today=today_str))

# %%
ttwa_code_name_df = glai_labelled[['ttwa_name','ttwa_code']].drop_duplicates().reset_index(drop=True)

ttwa_name_code_lookup =  {x:y for x,y in zip(ttwa_code_name_df.ttwa_name,ttwa_code_name_df.ttwa_code)}

def obtain_creative_econ_stats(ttwa_name):
    '''
    This function extracts creative economy stats for an area (based on its ttwa code)
    '''
    
    ttwa_code = ttwa_name_code_lookup[ttwa_name]
    
    
    #Subset the GlassAI data by the code
    ttwa_set = glai_labelled.loc[(glai_labelled.ttwa_code==ttwa_code) & (glai_labelled.source=='R2'),:]
    
    #Crosstab glai sector vs dcms sector to obtain creative capabilities
    ttwa_caps = pd.melt(pd.crosstab(ttwa_set.source_glai_sector,ttwa_set.dcms_sector).reset_index(drop=False),
                   id_vars='source_glai_sector')
    
    #Create totals of non-creative activity in the area
    ttwa_totals = glass_all.loc[glass_all.ttwa_code==ttwa_code,
                                ['glass_sector','business_count']].groupby(
        'glass_sector')['business_count'].sum().reset_index(drop=False)
    
    #Merge both
    ttwa_united = pd.merge(ttwa_caps,ttwa_totals,left_on='source_glai_sector',right_on='glass_sector')
    
    #Calculate shares of all non-creative businesses with creative capabilities
    ttwa_united['shares'] = ttwa_united['value']/( ttwa_united['value']+ttwa_united['business_count'])
    
    #Create three wide tables
    #One with business counts
    ttwa_united_total = pd.pivot_table(ttwa_united,index='dcms_sector',columns='glass_sector',values='value')
    
    #Complete columns
    for x in creative_embeddedness_non_cr_ranking:
        if x not in ttwa_united_total.columns:
            ttwa_united_total[x]=[0]*len(ttwa_united_total)
            
    for x in creative_embeddedness_cr_ranking:
        if x not in ttwa_united_total.index:
            ttwa_united_total.loc[x,:] = [0]*len(ttwa_united_total.columns)
    
    
    #One with shares of businesses in sector
    ttwa_united_shares = pd.pivot_table(ttwa_united,index='dcms_sector',columns='glass_sector',values='shares')
    #Fill zeroes
    ttwa_united_shares.fillna(value=0,inplace=True)
    
    #This normalises the shares by UK averages
    ttwa_united_normalised = ttwa_united_shares/national_mix_matrix
    
    #Fill zeroes
    ttwa_united_normalised.fillna(0,inplace=True)
    
    #How would we visualise this?
    
    
    
    return([ttwa_united_total,ttwa_united_shares,ttwa_united_normalised])
    #return(ttwa_totals)
                         
def extract_examples(creative,non_creative,place):
    '''
    Returns a dataframe with relevant examples
    
    '''
    
    matches = glai_labelled.loc[
        (glai_labelled.dcms_sector==creative) & 
        (glai_labelled.source_glai_sector==non_creative) & (glai_labelled.ttwa_name==place),:]
    
    return(matches)

# %%
#Data preparation

#Extract glass sectors
glass_sectors = list(set(glass_all.glass_sector))

#Set colors
set_colors = plt.matplotlib.cm.get_cmap('tab10').colors[:len(set(glai_labelled.dcms_sector.dropna()))]


#Set colors
sector_cols = {sector: color for sector, color in zip(set(glai_labelled.dcms_sector.dropna()),
                                                      set_colors)}

#Sort clusters by number of businesses
glai_labelled_sorted = glai_labelled.loc[glai_labelled.source=='R2',:].reset_index(
    drop=False).groupby('ttwa_name')['index'].count().sort_values(ascending=False).index

#off_stats_sorted = off_stats.loc[off_stats.sector=='creative_industries',:].sort_values('bc_2016',
#                                                                                        ascending=False).reset_index(drop=True)

#my_clusters = list(off_stats_sorted.ttwa_name[off_stats_sorted.is_cluster==True])

creative_clusters = list(off_stats.ttwa_name[off_stats.is_cluster==True])


ce_clusters_sorted = glai_labelled_sorted[[x in creative_clusters for x in glai_labelled_sorted]]

# %%
def rescale(vector,vmin,vmax):
    '''
    Rescales a vector with a new minimum and maximum
    
    '''
    vector = vector.dropna()
    
    try:
        rescaled = [((x - min(vector)) / (max(vector) - min(vector) )) * (vmax - vmin) + vmin for x in vector]
    except:
        #The above will fail if the vector is all zeroes (it tries to divide by zero)
        #In that case, we return a vector of zeroes
        
        rescaled = len(vector)*[0]
    
    return(rescaled)

# %%
#I need to decide where to normalise - everything?

#In that case I need to extract the data for all TTWAs, combine, melt, rescale and pivot, and
#then extract that by TTWA. It might still not work (London will probably dominate horribly)


#Extract values for all TTWAs and concatenate. NB we add the ttwa name to each output
all_ttwas_counts = pd.concat([pd.concat([
    pd.DataFrame({'ttwa_name':ttwa_name},index=creative_embeddedness_cr_ranking),
    obtain_creative_econ_stats(ttwa_name)[0]],axis=1) 
                   for ttwa_name in ce_clusters_sorted])

#Melt the dataframe
all_ttwas_counts_long = pd.melt(all_ttwas_counts.reset_index(drop=False),id_vars=['ttwa_name','index'])

#Create a variable where the zeroes are nans (we don't want to rescale them to zero)
all_ttwas_counts_long['value_2'] = [0 if x==0 else np.log(x) for x in all_ttwas_counts_long.value] 

#Rescale between 0 and 1
all_ttwas_counts_long['rescaled'] = rescale(all_ttwas_counts_long['value_2'],0,1)

# %%
#Order variables for plotting
ce_ttwas_ordered = all_ttwas_counts_long.groupby('ttwa_name')['value'].sum().sort_values(ascending=False).index

non_ce_sectors_ordered = all_ttwas_counts_long.groupby('variable')['value'].sum().sort_values(ascending=False).index

# %%
#Now we need to regroup these into area df

ttwas_ce_counts_norm = {x:pd.pivot_table(all_ttwas_counts_long.loc[all_ttwas_counts_long.ttwa_name==x],
                                    index='index',columns='variable',values='rescaled') for x in ce_clusters_sorted}

# %%
creative_embeddedness_cr_ranking
# Out:
# Index(['it_software', 'advertising_marketing', 'design', 'publishing',
#        'video_film_photography', 'music_performing_arts', 'architecture',
#        'crafts', 'libraries_museums'],
#       dtype='object', name='creative_sector_not_first')

# %%
#Create figurtes
fig,ax = plt.subplots(figsize=(18,10),ncols=len(glass_sectors),
                      nrows=len(ce_ttwas_ordered[:20]),
                      sharey='row',
                      sharex='col'
                     )


#We extract the data for each TTWA
for num_clust, ttwa_name in enumerate(ce_ttwas_ordered[:20]):
     
    #Extract the values
    all_values = obtain_creative_econ_stats(ttwa_name)

    #Loop over each sector to create the chart
    for num_sect,sector in enumerate(non_ce_sectors_ordered):
        
        #Extract indices of specialisation
        shares = all_values[2].loc[:,sector]
        
        #Create a vector with colors
        cols =  [sector_cols[ind] for ind in shares.index]
         
        #We extract the counts of creative economy businesses normalised and logged by UK totals 
        totals = ttwas_ce_counts_norm[ttwa_name].loc[:,sector]
        
        
        #Draw the scatter
        ax[num_clust][num_sect].bar(
            x=rescale(shares,0,4),
            height=totals,
            edgecolor=cols,linewidth=0.9,
            alpha=0.7,
            color=cols
        )
        
        #Draw removing ticks and labels
        ax[num_clust][num_sect].set_yticks([])
        ax[num_clust][num_sect].set_xticks([])
        ax[num_clust][num_sect].set_xticklabels([])
        
        #Set x and y limits so everything is in the same scale
        ax[num_clust][num_sect].set_ylim([0,1])
        
        #Change colors of some of the axes to make them invisible
        for pos in ['top','right']:
            ax[num_clust][num_sect].spines[pos].set_color('white')
         
        #Add sector names only for the top plot
        if num_clust==0:
            ax[num_clust][num_sect].set_title(" ".join([x+'\n' for x in sector.split(" ")]),size=9)
            
    #Add yticklabels on the left handside
    ax[num_clust][0].set_yticks([0.5])
    ax[num_clust][0].set_yticklabels([ttwa_name])
    
#Create legend in a hackly way
s1,s2,s3,s4,s5,s6,s7,s8,s9 = [plt.scatter([],[],s=40,marker='s',color=sector_cols[x],alpha=0.7) for x in 
                                       creative_embeddedness_cr_ranking]

#Add legend
plt.legend((s1,s2,s3,s4,s5,s6,s7,s8,s9),
          ({x:y for y,x in dcms_names_lookup.items()}[x] for x in creative_embeddedness_cr_ranking),
           scatterpoints=1,
           title='Creative sector',
           bbox_to_anchor=(-3,-1.5),
           ncol=2,
           fontsize=12)

#Add figure title
fig.suptitle('Creative capability presence in non creative sectors',y=1.02,size=16)

#Add another ax for the x labels
ax_final = fig.add_axes([0.5,-0.12,0.1,0.1])

ax_final.axis('off')
ax_final.set_title('Importance of creative capability in sector (normalised)',size=14)

#Add another ax for the y labels
ax_final_2 = fig.add_axes([1,0.6,0.03,0.1])

ax_final_2.axis('off')
ax_final_2.set_title('Total firms with creative capability in location',size=14,rotation=90)

#Final adjustments and saving
plt.tight_layout()
plt.subplots_adjust(wspace=0.2,hspace=0.2)
plt.savefig(fig_path+'/{today}_creative_econ.pdf'.format(today=today_str),bbox_inches='tight')
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/figure.py:1999: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
#Final analysis - is there any correlation between an area's specialisation in a creative sector and its 
# creative economy diffusion

ttwa_code_name_lookup = {y:x for x,y in ttwa_name_code_lookup.items()}



#Measuring diffusion: Creative LQ?

idbr_lqs = pd.read_csv(ext_data+'/29_11_2017_idbr_lqs_benchmarking.csv')


#Embedded totals
embedded_totals = glai_labelled.groupby(['source','ttwa_name','dcms_sector','ttwa_code'])['index'].count().reset_index(drop=False)

#Create two variable names (embeddded and specialist)
embedded_totals['sector'] = [y+'_glai_embedded' if x=='R2' else y+'_glai_spec' for x,y in zip(embedded_totals.source,
                                                                                embedded_totals.dcms_sector)]


#What do we want to do with this?
#Create an LQ for every variable?

#Create a creative embeddedness index by sector (% of creative businesses which are embedded)
embedded_short = embedded_totals[['ttwa_name','sector','index']]

embedded_short.rename(columns={'index':'business_count'},inplace=True)

#Concatenate with glass AI totals to do LQs
glass_ttwa_totals['ttwa_name'] = [ttwa_code_name_lookup[x] for x in glass_ttwa_totals['ttwa_code']]

#Here
embedded_totals = pd.concat([embedded_short,glass_ttwa_totals.drop('ttwa_code',axis=1)])

#all_glass_sectors_lq = create_lq_df(pd.pivot_table(embedded_totals,
#                                                  index='ttwa_name',columns='dcms_sector',))

#Create 2016 LQs dataframe (for creative sectors)
idbr_lqs_2016 = idbr_lqs.loc[idbr_lqs['year']==2016,:].drop('year',axis=1).set_index('ttwa_name')
idbr_lqs_2016.columns = [dcms_names_lookup[x]+'_official' for x in idbr_lqs_2016.columns]

combined_lq_df = pd.concat([create_lq_df(pd.pivot_table(embedded_totals,index='ttwa_name',columns='sector',
                                           values='business_count')),idbr_lqs_2016],axis=1)



#Merge with TTWA totals to normalsise
#embedded_totals = pd.merge(embedded_totals,glass_ttwa_totals,left_on='ttwa_code',right_on='ttwa_code')

#Calculate them as...
#Share of total firms in the location
#embedded_totals_lqs = pd.concat([create_lq_df(pd.pivot_table(embedded_totals,
#                                                            index='ttwa_name',columns='dcms_sector'))])
#Share of
# Out:
# /usr/local/lib/python3.5/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
combined_lq_df
# Out:
#                                 advertising_marketing_glai_embedded  \
# (pseudo) Channel Islands                                   0.321412
# (pseudo) Isle of Man                                       1.019864
# Aberdeen                                                   1.279829
# Aberystwyth                                                0.597554
# Alness and Invergordon                                          NaN
# Andover                                                    0.909135
# Arbroath and Montrose                                      2.164608
# Ashford                                                    1.301421
# Aviemore and Grantown-on-Spey                              7.071054
# Ayr                                                        0.358532
# Ballymena                                                  0.949843
# Banbury                                                    1.457393
# Bangor and Holyhead                                        1.455805
# Barnsley                                                   0.676362
# Barnstaple                                                 0.713714
# Barrow-in-Furness                                          0.359545
# Basingstoke                                                1.123224
# Bath                                                       1.017951
# Bedford                                                    0.879382
# Belfast                                                    1.277581
# Berwick                                                    0.623917
# Bideford                                                   0.207972
# Birkenhead                                                 0.741985
# Birmingham                                                 1.018336
# Blackburn                                                  1.174670
# Blackpool                                                  1.040304
# Blandford Forum and Gillingham                             0.461156
# Blyth and Ashington                                        0.289929
# Boston                                                     0.443481
# Bournemouth                                                1.330602
# ...                                                             ...
# Sunderland                                                 0.674624
# Swansea                                                    1.308897
# Swindon                                                    0.666770
# Taunton                                                    0.937713
# Telford                                                    0.707761
# Thetford and Mildenhall                                    0.578541
# Thurso                                                          NaN
# Torquay and Paignton                                       0.966187
# Trowbridge                                                 0.720900
# Tunbridge Wells                                            0.907430
# Turriff and Banff                                               NaN
# Tywyn and Dolgellau                                             NaN
# Ullapool                                                        NaN
# Wadebridge                                                 0.524501
# Wakefield and Castleford                                   0.480298
# Warrington and Wigan                                       1.107995
# Western Isles                                                   NaN
# Weston-super-Mare                                          1.287504
# Whitby                                                          NaN
# Whitehaven                                                 2.597530
# Wick                                                       4.545677
# Wisbech                                                    1.375989
# Wolverhampton and Walsall                                  0.703324
# Worcester and Kidderminster                                0.929798
# Workington                                                 0.587894
# Worksop and Retford                                        0.566188
# Worthing                                                   1.360844
# Wrexham                                                    0.589254
# Yeovil                                                     0.681477
# York                                                       1.368291
#
#                                 advertising_marketing_glai_spec  \
# (pseudo) Channel Islands                               1.528092
# (pseudo) Isle of Man                                   0.510395
# Aberdeen                                               0.656508
# Aberystwyth                                            0.448573
# Alness and Invergordon                                      NaN
# Andover                                                0.909962
# Arbroath and Montrose                                  0.433315
# Ashford                                                1.074648
# Aviemore and Grantown-on-Spey                               NaN
# Ayr                                                    0.986860
# Ballymena                                              0.316902
# Banbury                                                1.256118
# Bangor and Holyhead                                    0.104081
# Barnsley                                               0.830835
# Barnstaple                                             0.952483
# Barrow-in-Furness                                      0.719744
# Basingstoke                                            1.139037
# Bath                                                   1.352646
# Bedford                                                0.787530
# Belfast                                                1.068948
# Berwick                                                0.624483
# Bideford                                               1.353048
# Birkenhead                                             0.799787
# Birmingham                                             1.176071
# Blackburn                                              0.778062
# Blackpool                                              0.860163
# Blandford Forum and Gillingham                         0.538504
# Blyth and Ashington                                    0.652934
# Boston                                                      NaN
# Bournemouth                                            1.136632
# ...                                                         ...
# Sunderland                                             0.675237
# Swansea                                                0.632456
# Swindon                                                1.001064
# Taunton                                                0.531854
# Telford                                                0.501786
# Thetford and Mildenhall                                0.463253
# Thurso                                                      NaN
# Torquay and Paignton                                   0.676945
# Trowbridge                                             1.002160
# Tunbridge Wells                                        1.075564
# Turriff and Banff                                           NaN
# Tywyn and Dolgellau                                         NaN
# Ullapool                                                    NaN
# Wadebridge                                             0.524978
# Wakefield and Castleford                               0.871331
# Warrington and Wigan                                   0.515452
# Western Isles                                               NaN
# Weston-super-Mare                                      0.705702
# Whitby                                                      NaN
# Whitehaven                                                  NaN
# Wick                                                        NaN
# Wisbech                                                0.172155
# Wolverhampton and Walsall                              0.647192
# Worcester and Kidderminster                            0.568726
# Workington                                             0.147107
# Worksop and Retford                                    0.226681
# Worthing                                               1.201836
# Wrexham                                                0.294895
# Yeovil                                                 0.445986
# York                                                   0.754641
#
#                                 architecture_glai_embedded  \
# (pseudo) Channel Islands                          1.677098
# (pseudo) Isle of Man                              1.064312
# Aberdeen                                          0.500853
# Aberystwyth                                       1.558993
# Alness and Invergordon                                 NaN
# Andover                                           0.790632
# Arbroath and Montrose                             1.129474
# Ashford                                           1.018606
# Aviemore and Grantown-on-Spey                          NaN
# Ayr                                                    NaN
# Ballymena                                         1.652067
# Banbury                                                NaN
# Bangor and Holyhead                               1.085181
# Barnsley                                          0.641672
# Barnstaple                                        0.310342
# Barrow-in-Furness                                 0.938038
# Basingstoke                                       0.539818
# Bath                                              1.465264
# Bedford                                           1.086760
# Belfast                                           2.135302
# Berwick                                                NaN
# Bideford                                          2.170362
# Birkenhead                                        1.340175
# Birmingham                                        0.902629
# Blackburn                                         0.901372
# Blackpool                                         1.416057
# Blandford Forum and Gillingham                    1.203136
# Blyth and Ashington                               1.134620
# Boston                                            0.578511
# Bournemouth                                       1.077357
# ...                                                    ...
# Sunderland                                        1.026704
# Swansea                                           0.471015
# Swindon                                           1.288574
# Taunton                                           1.794067
# Telford                                           0.615506
# Thetford and Mildenhall                           2.415022
# Thurso                                                 NaN
# Torquay and Paignton                              0.336099
# Trowbridge                                        1.567332
# Tunbridge Wells                                   1.059121
# Turriff and Banff                                      NaN
# Tywyn and Dolgellau                                    NaN
# Ullapool                                               NaN
# Wadebridge                                             NaN
# Wakefield and Castleford                          0.939808
# Warrington and Wigan                              0.895714
# Western Isles                                          NaN
# Weston-super-Mare                                 0.959727
# Whitby                                            1.844808
# Whitehaven                                             NaN
# Wick                                                   NaN
# Wisbech                                           2.692423
# Wolverhampton and Walsall                         0.887876
# Worcester and Kidderminster                       0.539067
# Workington                                        1.150342
# Worksop and Retford                               0.886296
# Worthing                                          0.208846
# Wrexham                                           0.768670
# Yeovil                                            1.777945
# York                                              1.165653
#
#                                 architecture_glai_spec  crafts_glai_embedded  \
# (pseudo) Channel Islands                      2.010959              0.491447
# (pseudo) Isle of Man                          1.276186              2.495036
# Aberdeen                                      0.800744              0.978446
# Aberystwyth                                   0.934671              4.568376
# Alness and Invergordon                        4.147603                   NaN
# Andover                                       0.158004              1.235637
# Arbroath and Montrose                              NaN                   NaN
# Ashford                                       1.017817              0.994953
# Aviemore and Grantown-on-Spey                      NaN                   NaN
# Ayr                                           0.841204              1.644615
# Ballymena                                     1.980945                   NaN
# Banbury                                       0.886511              0.990396
# Bangor and Holyhead                           0.975907                   NaN
# Barnsley                                      0.288529              1.316222
# Barnstaple                                    0.930303              1.091287
# Barrow-in-Furness                                  NaN              1.099507
# Basingstoke                                   0.508577              0.813523
# Bath                                          2.086384              1.073430
# Bedford                                       0.506762              1.273829
# Belfast                                       1.998343              0.671500
# Berwick                                       0.975907                   NaN
# Bideford                                      1.301209              1.271979
# Birkenhead                                    0.803482              0.872703
# Birmingham                                    0.929158              1.616949
# Blackburn                                     0.486364              0.950877
# Blackpool                                     0.212244              1.244858
# Blandford Forum and Gillingham                0.721322              2.820476
# Blyth and Ashington                           0.226748              0.886619
# Boston                                        0.346838              1.356187
# Bournemouth                                   0.897102              1.403121
# ...                                                ...                   ...
# Sunderland                                    0.527610              0.687678
# Swansea                                       0.352987              1.518256
# Swindon                                       0.927054              0.830711
# Taunton                                       1.466736              1.720546
# Telford                                       0.830289              0.901820
# Thetford and Mildenhall                       0.542959              0.707683
# Thurso                                             NaN                   NaN
# Torquay and Paignton                          1.108266              1.969765
# Trowbridge                                    0.689092              1.224750
# Tunbridge Wells                               1.307312              1.168407
# Turriff and Banff                             3.981699                   NaN
# Tywyn and Dolgellau                                NaN                   NaN
# Ullapool                                           NaN                   NaN
# Wadebridge                                    1.093873              3.207904
# Wakefield and Castleford                      1.032988              1.285179
# Warrington and Wigan                          0.341735              1.097620
# Western Isles                                      NaN                   NaN
# Weston-super-Mare                             0.383593              1.499906
# Whitby                                             NaN                   NaN
# Whitehaven                                         NaN                   NaN
# Wick                                               NaN                   NaN
# Wisbech                                       0.269034              1.051961
# Wolverhampton and Walsall                     0.496825              1.110091
# Worcester and Kidderminster                   0.861840              1.053100
# Workington                                    0.229890              0.449452
# Worksop and Retford                           0.531366              2.424003
# Worthing                                      1.001685              0.244796
# Wrexham                                       0.307230              1.201314
# Yeovil                                        0.737959              2.404607
# York                                          1.048275              0.853940
#
#                                 crafts_glai_spec  design_glai_embedded  \
# (pseudo) Channel Islands                2.058257              0.360509
# (pseudo) Isle of Man                         NaN              0.915139
# Aberdeen                                0.512236              1.112522
# Aberystwyth                             2.869964                   NaN
# Alness and Invergordon                  8.490310                   NaN
# Andover                                 0.323440              0.793121
# Arbroath and Montrose                        NaN                   NaN
# Ashford                                 1.250107              1.021812
# Aviemore and Grantown-on-Spey                NaN              2.643735
# Ayr                                     0.573993              1.005364
# Ballymena                               3.041305              1.775643
# Banbury                                 0.259246              1.271415
# Bangor and Holyhead                          NaN              0.933083
# Barnsley                                0.393754              1.241406
# Barnstaple                              1.904369              1.334222
# Barrow-in-Furness                       2.302457                   NaN
# Basingstoke                             0.283930              0.895162
# Bath                                    1.348709              1.338637
# Bedford                                 0.444584              0.986354
# Belfast                                 0.575253              1.141915
# Berwick                                      NaN              0.699812
# Bideford                                1.331813              2.099437
# Birkenhead                              1.096506              0.960281
# Birmingham                              2.424559              0.951842
# Blackburn                               1.106229              1.240058
# Blackpool                               2.027537              0.963921
# Blandford Forum and Gillingham          0.984384              1.379340
# Blyth and Ashington                     1.392488              0.975593
# Boston                                       NaN              0.746141
# Bournemouth                             1.101843              1.235141
# ...                                          ...                   ...
# Sunderland                              0.540020              1.135031
# Swansea                                 0.867095              0.911245
# Swindon                                 0.869787              0.941773
# Taunton                                 0.600493              0.981662
# Telford                                 0.944242              1.058474
# Thetford and Mildenhall                 0.740973              1.427617
# Thurso                                       NaN                   NaN
# Torquay and Paignton                    0.618727              1.083717
# Trowbridge                              1.410599              1.482422
# Tunbridge Wells                         1.146909              1.339228
# Turriff and Banff                            NaN                   NaN
# Tywyn and Dolgellau                          NaN              1.551758
# Ullapool                                     NaN              5.948405
# Wadebridge                              1.119601              1.961013
# Wakefield and Castleford                1.153401              1.077447
# Warrington and Wigan                    0.249837              0.892698
# Western Isles                                NaN                   NaN
# Weston-super-Mare                       0.392615              1.237818
# Whitby                                  2.264083              0.793121
# Whitehaven                                   NaN              0.485584
# Wick                                         NaN                   NaN
# Wisbech                                      NaN              1.157527
# Wolverhampton and Walsall               0.726444              1.043357
# Worcester and Kidderminster             0.661583              1.274658
# Workington                              1.882378              1.978222
# Worksop and Retford                     0.725151              1.524146
# Worthing                                1.025245              0.897872
# Wrexham                                      NaN              1.211712
# Yeovil                                  0.839240              1.469952
# York                                    0.536465              0.970955
#
#                                 design_glai_spec  it_software_glai_embedded  \
# (pseudo) Channel Islands                0.415458                   0.904671
# (pseudo) Isle of Man                    0.175771                   1.476304
# Aberdeen                                0.716868                   1.235078
# Aberystwyth                             0.514933                   0.720825
# Alness and Invergordon                       NaN                        NaN
# Andover                                 1.479820                   0.812358
# Arbroath and Montrose                   0.373064                   1.740767
# Ashford                                 0.897184                   1.334410
# Aviemore and Grantown-on-Spey                NaN                        NaN
# Ayr                                     0.463440                   1.369567
# Ballymena                               0.545676                   1.018479
# Banbury                                 0.976801                   1.432478
# Bangor and Holyhead                     0.716868                   0.919876
# Barnsley                                0.794788                   0.988957
# Barnstaple                              0.307516                   1.147930
# Barrow-in-Furness                       0.309833                   0.722861
# Basingstoke                             0.764149                   1.271738
# Bath                                    1.996396                   1.002117
# Bedford                                 0.797679                   1.023571
# Belfast                                 0.997724                   1.027424
# Berwick                                 0.537651                   0.501750
# Bideford                                0.716868                   1.338001
# Birkenhead                              0.590211                   0.940951
# Birmingham                              0.860661                   1.228411
# Blackburn                               0.803849                   1.208614
# Blackpool                               0.545676                   1.163975
# Blandford Forum and Gillingham          1.059718                   0.803528
# Blyth and Ashington                     1.124291                   0.408029
# Boston                                  0.191082                   0.891612
# Bournemouth                             0.929163                   1.042389
# ...                                          ...                        ...
# Sunderland                              0.436010                   0.881609
# Swansea                                 0.583408                   1.161499
# Swindon                                 0.766106                   1.241234
# Taunton                                 0.808061                   0.779241
# Telford                                 0.813203                   1.280649
# Thetford and Mildenhall                 0.498549                   0.977045
# Thurso                                       NaN                        NaN
# Torquay and Paignton                    0.832597                   0.932403
# Trowbridge                              1.311476                   0.966241
# Tunbridge Wells                         1.028901                   0.989004
# Turriff and Banff                            NaN                        NaN
# Tywyn and Dolgellau                          NaN                   0.556289
# Ullapool                                     NaN                        NaN
# Wadebridge                              0.301321                   1.406004
# Wakefield and Castleford                0.672571                   0.603521
# Warrington and Wigan                    0.672393                   1.324016
# Western Isles                                NaN                        NaN
# Weston-super-Mare                       0.845324                   1.429844
# Whitby                                  3.046689                   0.568651
# Whitehaven                              0.746128                   0.696307
# Wick                                         NaN                        NaN
# Wisbech                                 0.444652                   1.175723
# Wolverhampton and Walsall               0.547426                   0.939642
# Worcester and Kidderminster             0.860591                   1.190843
# Workington                              0.886565                   1.063757
# Worksop and Retford                     0.780646                   1.320443
# Worthing                                1.034724                   0.611568
# Wrexham                                 0.592412                   0.987241
# Yeovil                                  0.677600                   1.412258
# York                                    0.938471                   0.931948
#
#                                 it_software_glai_spec           ...            \
# (pseudo) Channel Islands                     0.861973           ...
# (pseudo) Isle of Man                         1.148745           ...
# Aberdeen                                     1.098333           ...
# Aberystwyth                                  0.560890           ...
# Alness and Invergordon                            NaN           ...
# Andover                                      0.785627           ...
# Arbroath and Montrose                        0.580513           ...
# Ashford                                      0.540981           ...
# Aviemore and Grantown-on-Spey                     NaN           ...
# Ayr                                          0.480762           ...
# Ballymena                                    0.254732           ...
# Banbury                                      0.977122           ...
# Bangor and Holyhead                          0.780846           ...
# Barnsley                                     0.676087           ...
# Barnstaple                                   0.733724           ...
# Barrow-in-Furness                            0.482121           ...
# Basingstoke                                  1.403098           ...
# Bath                                         1.139060           ...
# Bedford                                      0.856457           ...
# Belfast                                      1.204545           ...
# Berwick                                      0.167324           ...
# Bideford                                     0.780846           ...
# Birkenhead                                   0.857180           ...
# Birmingham                                   1.190441           ...
# Blackburn                                    0.769037           ...
# Blackpool                                    0.679286           ...
# Blandford Forum and Gillingham               1.030620           ...
# Blyth and Ashington                          0.660912           ...
# Boston                                       0.178401           ...
# Bournemouth                                  1.181282           ...
# ...                                               ...           ...
# Sunderland                                   0.708615           ...
# Swansea                                      0.702050           ...
# Swindon                                      1.125883           ...
# Taunton                                      0.553255           ...
# Telford                                      0.933232           ...
# Thetford and Mildenhall                      0.961962           ...
# Thurso                                            NaN           ...
# Torquay and Paignton                         0.829169           ...
# Trowbridge                                   0.880742           ...
# Tunbridge Wells                              0.826136           ...
# Turriff and Banff                            0.682683           ...
# Tywyn and Dolgellau                          0.742046           ...
# Ullapool                                          NaN           ...
# Wadebridge                                   0.140663           ...
# Wakefield and Castleford                     0.740646           ...
# Warrington and Wigan                         0.732402           ...
# Western Isles                                     NaN           ...
# Weston-super-Mare                            0.871440           ...
# Whitby                                       0.189634           ...
# Whitehaven                                   0.464410           ...
# Wick                                              NaN           ...
# Wisbech                                      0.645781           ...
# Wolverhampton and Walsall                    0.711888           ...
# Worcester and Kidderminster                  0.895836           ...
# Workington                                   0.315327           ...
# Worksop and Retford                          0.759211           ...
# Worthing                                     1.352485           ...
# Wrexham                                      0.895494           ...
# Yeovil                                       0.731044           ...
# York                                         0.606596           ...
#
#                                 advertising_marketing_official  \
# (pseudo) Channel Islands                                   NaN
# (pseudo) Isle of Man                                       NaN
# Aberdeen                                              0.339683
# Aberystwyth                                           0.275406
# Alness and Invergordon                                0.622082
# Andover                                               0.726260
# Arbroath and Montrose                                 0.000000
# Ashford                                               1.026963
# Aviemore and Grantown-on-Spey                         0.000000
# Ayr                                                   0.489116
# Ballymena                                                  NaN
# Banbury                                               1.110470
# Bangor and Holyhead                                   0.218501
# Barnsley                                              0.536054
# Barnstaple                                            0.726193
# Barrow-in-Furness                                     0.521851
# Basingstoke                                           1.123027
# Bath                                                  1.400958
# Bedford                                               0.833403
# Belfast                                                    NaN
# Berwick                                               0.000000
# Bideford                                              0.469883
# Birkenhead                                            0.692825
# Birmingham                                            0.780759
# Blackburn                                             0.642736
# Blackpool                                             1.737306
# Blandford Forum and Gillingham                        0.577197
# Blyth and Ashington                                   0.317156
# Boston                                                0.192361
# Bournemouth                                           1.064193
# ...                                                        ...
# Sunderland                                            0.474141
# Swansea                                               0.252916
# Swindon                                               0.912252
# Taunton                                               0.432640
# Telford                                               0.630182
# Thetford and Mildenhall                               0.409458
# Thurso                                                0.000000
# Torquay and Paignton                                  0.631701
# Trowbridge                                            0.725762
# Tunbridge Wells                                       1.663784
# Turriff and Banff                                     0.000000
# Tywyn and Dolgellau                                   0.000000
# Ullapool                                              0.000000
# Wadebridge                                            0.572080
# Wakefield and Castleford                              0.550812
# Warrington and Wigan                                  0.608321
# Western Isles                                         0.000000
# Weston-super-Mare                                     0.624759
# Whitby                                                0.403990
# Whitehaven                                            0.000000
# Wick                                                  0.000000
# Wisbech                                               0.511967
# Wolverhampton and Walsall                             0.498788
# Worcester and Kidderminster                           0.804798
# Workington                                            0.000000
# Worksop and Retford                                   0.416984
# Worthing                                              0.830358
# Wrexham                                               0.587069
# Yeovil                                                0.530098
# York                                                  0.787704
#
#                                 architecture_official  crafts_official  \
# (pseudo) Channel Islands                          NaN              NaN
# (pseudo) Isle of Man                              NaN              NaN
# Aberdeen                                     1.274718         0.000000
# Aberystwyth                                  0.555649         0.000000
# Alness and Invergordon                       0.941319         0.000000
# Andover                                      0.439583         0.000000
# Arbroath and Montrose                        1.162454         0.000000
# Ashford                                      0.988893         0.900814
# Aviemore and Grantown-on-Spey                0.000000         0.000000
# Ayr                                          0.555088         0.000000
# Ballymena                                         NaN              NaN
# Banbury                                      1.120223         0.000000
# Bangor and Holyhead                          0.495945         0.000000
# Barnsley                                     0.463510         0.000000
# Barnstaple                                   0.676220         0.000000
# Barrow-in-Furness                            0.676845         0.000000
# Basingstoke                                  0.883655         0.866868
# Bath                                         1.861371         2.637570
# Bedford                                      1.070011         0.000000
# Belfast                                           NaN              NaN
# Berwick                                      0.718691         0.000000
# Bideford                                     1.066523         0.000000
# Birkenhead                                   0.587085         1.069587
# Birmingham                                   0.879200         4.993052
# Blackburn                                    0.416816         0.000000
# Blackpool                                    0.508809         0.000000
# Blandford Forum and Gillingham               0.873400         0.000000
# Blyth and Ashington                          0.479912         0.000000
# Boston                                       0.582151         0.000000
# Bournemouth                                  0.805155         0.733441
# ...                                               ...              ...
# Sunderland                                   0.627776         1.143722
# Swansea                                      0.535788         0.976132
# Swindon                                      0.966277         0.000000
# Taunton                                      1.018360         1.855311
# Telford                                      0.688693         1.351220
# Thetford and Mildenhall                      0.619582         0.000000
# Thurso                                       0.000000         0.000000
# Torquay and Paignton                         1.323517         0.000000
# Trowbridge                                   1.098205         2.500974
# Tunbridge Wells                              1.545455         1.271564
# Turriff and Banff                            0.589651         0.000000
# Tywyn and Dolgellau                          0.550636         0.000000
# Ullapool                                     0.000000         0.000000
# Wadebridge                                   0.432829         0.000000
# Wakefield and Castleford                     0.635028         0.000000
# Warrington and Wigan                         0.797763         0.000000
# Western Isles                                1.038298         0.000000
# Weston-super-Mare                            0.819320         1.607510
# Whitby                                       0.611307         0.000000
# Whitehaven                                   1.219560         0.000000
# Wick                                         1.254017         0.000000
# Wisbech                                      0.516464         0.000000
# Wolverhampton and Walsall                    0.704437         1.283387
# Worcester and Kidderminster                  0.897326         1.634804
# Workington                                   0.462048         0.000000
# Worksop and Retford                          0.420647         0.000000
# Worthing                                     0.957315         0.000000
# Wrexham                                      0.710671         0.000000
# Yeovil                                       0.701865         1.278701
# York                                         0.970178         0.707013
#
#                                 design_official  \
# (pseudo) Channel Islands                    NaN
# (pseudo) Isle of Man                        NaN
# Aberdeen                               0.558246
# Aberystwyth                            0.198514
# Alness and Invergordon                 0.000000
# Andover                                1.256380
# Arbroath and Montrose                  0.415303
# Ashford                                1.009418
# Aviemore and Grantown-on-Spey          0.000000
# Ayr                                    0.330522
# Ballymena                                   NaN
# Banbury                                1.100594
# Bangor and Holyhead                    0.413428
# Barnsley                               0.620984
# Barnstaple                             0.543576
# Barrow-in-Furness                      0.644833
# Basingstoke                            1.311363
# Bath                                   1.921115
# Bedford                                1.037608
# Belfast                                     NaN
# Berwick                                0.000000
# Bideford                               0.508041
# Birkenhead                             0.599270
# Birmingham                             0.696924
# Blackburn                              0.645292
# Blackpool                              0.545338
# Blandford Forum and Gillingham         0.936104
# Blyth and Ashington                    0.457215
# Boston                                 0.207982
# Bournemouth                            0.821866
# ...                                         ...
# Sunderland                             0.576726
# Swansea                                0.410182
# Swindon                                0.821944
# Taunton                                0.727647
# Telford                                0.681357
# Thetford and Mildenhall                0.442709
# Thurso                                 0.817629
# Torquay and Paignton                   0.630461
# Trowbridge                             1.064949
# Tunbridge Wells                        1.318002
# Turriff and Banff                      0.000000
# Tywyn and Dolgellau                    0.000000
# Ullapool                               1.157704
# Wadebridge                             0.927805
# Wakefield and Castleford               0.595541
# Warrington and Wigan                   0.591948
# Western Isles                          0.000000
# Weston-super-Mare                      0.720526
# Whitby                                 0.000000
# Whitehaven                             0.435705
# Wick                                   0.000000
# Wisbech                                0.184514
# Wolverhampton and Walsall              0.611199
# Worcester and Kidderminster            0.824355
# Workington                             0.495220
# Worksop and Retford                    0.601128
# Worthing                               1.325306
# Wrexham                                0.444320
# Yeovil                                 0.644789
# York                                   0.792252
#
#                                 video_film_photography_official  \
# (pseudo) Channel Islands                                    NaN
# (pseudo) Isle of Man                                        NaN
# Aberdeen                                               0.313504
# Aberystwyth                                            0.273313
# Alness and Invergordon                                 0.000000
# Andover                                                0.432445
# Arbroath and Montrose                                  0.285894
# Ashford                                                0.625393
# Aviemore and Grantown-on-Spey                          0.610553
# Ayr                                                    0.182024
# Ballymena                                                   NaN
# Banbury                                                0.792085
# Bangor and Holyhead                                    0.772495
# Barnsley                                               0.455983
# Barnstaple                                             0.415774
# Barrow-in-Furness                                      0.277439
# Basingstoke                                            0.769000
# Bath                                                   1.169897
# Bedford                                                0.695490
# Belfast                                                     NaN
# Berwick                                                0.176755
# Bideford                                               0.174867
# Birkenhead                                             0.474416
# Birmingham                                             0.547333
# Blackburn                                              0.290450
# Blackpool                                              0.354554
# Blandford Forum and Gillingham                         0.859216
# Blyth and Ashington                                    0.314746
# Boston                                                 0.000000
# Bournemouth                                            0.664781
# ...                                                         ...
# Sunderland                                             0.308791
# Swansea                                                0.508263
# Swindon                                                0.645040
# Taunton                                                0.500911
# Telford                                                0.442987
# Thetford and Mildenhall                                0.355553
# Thurso                                                 0.000000
# Torquay and Paignton                                   0.651012
# Trowbridge                                             0.694524
# Tunbridge Wells                                        1.177050
# Turriff and Banff                                      0.000000
# Tywyn and Dolgellau                                    0.541694
# Ullapool                                               0.000000
# Wadebridge                                             0.638699
# Wakefield and Castleford                               0.195224
# Warrington and Wigan                                   0.437681
# Western Isles                                          1.021436
# Weston-super-Mare                                      0.713013
# Whitby                                                 0.300690
# Whitehaven                                             0.149969
# Wick                                                   0.000000
# Wisbech                                                0.381058
# Wolverhampton and Walsall                              0.321749
# Worcester and Kidderminster                            0.488667
# Workington                                             0.170454
# Worksop and Retford                                    0.258635
# Worthing                                               0.853478
# Wrexham                                                0.393260
# Yeovil                                                 0.542510
# York                                                   0.599923
#
#                                 it_software_official  \
# (pseudo) Channel Islands                         NaN
# ...
# Alness and Invergordon                      0.217375
# Andover                                     1.154689
# Arbroath and Montrose                       0.268441
# Ashford                                     0.799263
# Aviemore and Grantown-on-Spey               0.143320
# Ayr                                         0.384552
# Ballymena                                        NaN
# Banbury                                     0.856905
# Bangor and Holyhead                         0.276772
# Barnsley                                    0.555251
# Barnstaple                                  0.351352
# Barrow-in-Furness                           0.338652
# Basingstoke                                 2.307432
# Bath                                        1.110416
# Bedford                                     1.041321
# Belfast                                          NaN
# Berwick                                     0.248946
# Bideford                                    0.246288
# Birkenhead                                  0.798912
# Birmingham                                  0.912841
# Blackburn                                   0.449183
# Blackpool                                   0.768627
# Blandford Forum and Gillingham              0.554649
# Blyth and Ashington                         0.452532
# Boston                                      0.201650
# Bournemouth                                 0.989419
# ...                                              ...
# Sunderland                                  0.476329
# Swansea                                     0.517003
# Swindon                                     1.391958
# Taunton                                     0.537521
# Telford                                     0.874704
# Thetford and Mildenhall                     0.333847
# Thurso                                      0.132123
# Torquay and Paignton                        0.517880
# Trowbridge                                  0.905728
# Tunbridge Wells                             1.113827
# Turriff and Banff                           0.136165
# Tywyn and Dolgellau                         0.190734
# Ullapool                                    0.187077
# Wadebridge                                  0.199903
# Wakefield and Castleford                    0.513255
# Warrington and Wigan                        0.774095
# Western Isles                               0.159846
# Weston-super-Mare                           0.807747
# Whitby                                      0.176458
# Whitehaven                                  0.316831
# Wick                                        0.000000
# Wisbech                                     0.417427
# Wolverhampton and Walsall                   0.596466
# Worcester and Kidderminster                 0.714154
# Workington                                  0.213398
# Worksop and Retford                         0.509975
# Worthing                                    1.070801
# Wrexham                                     0.400023
# Yeovil                                      0.555698
# York                                        0.777736
#
#                                 libraries_museums_official  \
# (pseudo) Channel Islands                               NaN
# (pseudo) Isle of Man                                   NaN
# Aberdeen                                          1.554661
# Aberystwyth                                       1.658524
# Alness and Invergordon                            0.000000
# Andover                                           0.000000
# Arbroath and Montrose                             0.000000
# Ashford                                           0.000000
# Aviemore and Grantown-on-Spey                     2.469983
# Ayr                                               2.209131
# Ballymena                                              NaN
# Banbury                                           1.393203
# Bangor and Holyhead                               2.631675
# Barnsley                                          0.000000
# Barnstaple                                        1.345605
# Barrow-in-Furness                                 0.897899
# Basingstoke                                       0.541040
# Bath                                              1.234643
# Bedford                                           0.912517
# Belfast                                                NaN
# Berwick                                           2.860235
# Bideford                                          0.707422
# Birkenhead                                        1.335126
# Birmingham                                        0.984101
# Blackburn                                         0.829419
# Blackpool                                         0.843730
# Blandford Forum and Gillingham                    1.737973
# Blyth and Ashington                               0.954974
# Boston                                            0.000000
# Bournemouth                                       0.915527
# ...                                                    ...
# Sunderland                                        0.892291
# Swansea                                           2.132322
# Swindon                                           0.732491
# Taunton                                           0.578979
# Telford                                           0.843339
# Thetford and Mildenhall                           0.821935
# Thurso                                            0.000000
# Torquay and Paignton                              1.170514
# Trowbridge                                        0.936562
# Tunbridge Wells                                   0.892826
# Turriff and Banff                                 2.346683
# Tywyn and Dolgellau                               2.191413
# Ullapool                                          0.000000
# Wadebridge                                        1.722565
# Wakefield and Castleford                          1.421592
# Warrington and Wigan                              0.976900
# Western Isles                                     2.754801
# Weston-super-Mare                                 0.752473
# Whitby                                            2.432871
# Whitehaven                                        1.820096
# Wick                                              0.000000
# Wisbech                                           0.513854
# Wolverhampton and Walsall                         1.268253
# Worcester and Kidderminster                       1.147874
# Workington                                        1.838852
# Worksop and Retford                               0.000000
# Worthing                                          1.190596
# Wrexham                                           1.767698
# Yeovil                                            1.596155
# York                                              1.103172
#
#                                 music_performing_arts_official  \
# (pseudo) Channel Islands                                   NaN
# (pseudo) Isle of Man                                       NaN
# Aberdeen                                              0.269529
# Aberystwyth                                           0.520302
# Alness and Invergordon                                0.000000
# Andover                                               0.926144
# Arbroath and Montrose                                 0.272126
# Ashford                                               0.694489
# Aviemore and Grantown-on-Spey                         0.000000
# Ayr                                                   0.563091
# Ballymena                                                  NaN
# Banbury                                               1.147301
# Bangor and Holyhead                                   0.851393
# Barnsley                                              0.596783
# Barnstaple                                            0.435327
# Barrow-in-Furness                                     0.422525
# Basingstoke                                           0.684230
# Bath                                                  1.815584
# Bedford                                               0.733565
# Belfast                                                    NaN
# Berwick                                               0.168243
# Bideford                                              0.332892
# Birkenhead                                            0.667538
# Birmingham                                            0.492032
# Blackburn                                             0.374038
# Blackpool                                             0.516145
# Blandford Forum and Gillingham                        1.022299
# Blyth and Ashington                                   0.374486
# Boston                                                0.272559
# Bournemouth                                           0.673157
# ...                                                        ...
# Sunderland                                            0.335909
# Swansea                                               0.609212
# Swindon                                               0.732463
# Taunton                                               0.681126
# Telford                                               0.446457
# Thetford and Mildenhall                               0.386778
# Thurso                                                0.000000
# Torquay and Paignton                                  0.826214
# Trowbridge                                            1.101796
# Tunbridge Wells                                       1.342106
# Turriff and Banff                                     0.000000
# Tywyn and Dolgellau                                   0.257804
# Ullapool                                              0.000000
# Wadebridge                                            0.405294
# Wakefield and Castleford                              0.353062
# Warrington and Wigan                                  0.344775
# Western Isles                                         0.324082
# Weston-super-Mare                                     0.560646
# Whitby                                                0.286210
# Whitehaven                                            0.356868
# Wick                                                  0.000000
# Wisbech                                               0.181353
# Wolverhampton and Walsall                             0.306254
# Worcester and Kidderminster                           0.555160
# Workington                                            0.540819
# Worksop and Retford                                   0.246180
# Worthing                                              0.980455
# Wrexham                                               0.415913
# Yeovil                                                0.868464
# York                                                  0.571032
#
#                                 publishing_official  not_in_sector_official
# (pseudo) Channel Islands                        NaN                     NaN
# (pseudo) Isle of Man                            NaN                     NaN
# Aberdeen                                   0.361641                1.053788
# Aberystwyth                                1.628940                1.068736
# Alness and Invergordon                     0.000000                1.084612
# Andover                                    0.644341                1.007016
# Arbroath and Montrose                      0.851961                1.072230
# Ashford                                    0.724759                1.021512
# Aviemore and Grantown-on-Spey              0.000000                1.088616
# Ayr                                        0.271216                1.062620
# Ballymena                                       NaN                     NaN
# Banbury                                    0.821011                1.006175
# Bangor and Holyhead                        0.726956                1.056891
# Barnsley                                   0.934192                1.048161
# Barnstaple                                 0.247800                1.059838
# Barrow-in-Furness                          0.661412                1.062353
# Basingstoke                                0.697448                0.937382
# Bath                                       3.031549                0.955398
# Bedford                                    0.672180                1.007765
# Belfast                                         NaN                     NaN
# Berwick                                    0.000000                1.081304
# Bideford                                   1.042205                1.067606
# Birkenhead                                 0.614677                1.031040
# Birmingham                                 0.674569                1.021470
# Blackburn                                  0.305484                1.059065
# Blackpool                                  0.870113                1.027627
# Blandford Forum and Gillingham             1.280228                1.028145
# Blyth and Ashington                        0.703454                1.060942
# Boston                                     0.639987                1.083618
# Bournemouth                                1.053745                1.011031
# ...                                             ...                     ...
# Sunderland                                 0.328641                1.058024
# Swansea                                    0.448776                1.051600
# Swindon                                    0.944245                0.990914
# Taunton                                    1.172843                1.041391
# Telford                                    0.621222                1.030163
# Thetford and Mildenhall                    0.756819                1.064914
# Thurso                                     0.000000                1.093543
# Torquay and Paignton                       1.616674                1.034005
# Trowbridge                                 1.149819                1.007512
# Tunbridge Wells                            2.119174                0.970790
# Turriff and Banff                          0.000000                1.093120
# Tywyn and Dolgellau                        0.807121                1.077411
# Ullapool                                   0.000000                1.087786
# Wadebridge                                 0.634439                1.062881
# Wakefield and Castleford                   0.407235                1.055773
# Warrington and Wigan                       0.314827                1.038812
# Western Isles                              1.014623                1.067612
# Weston-super-Mare                          0.369525                1.028858
# Whitby                                     0.896053                1.075957
# Whitehaven                                 0.000000                1.070503
# Wick                                       0.000000                1.099801
# Wisbech                                    0.378516                1.066776
# Wolverhampton and Walsall                  0.417942                1.049967
# Worcester and Kidderminster                0.845549                1.031014
# Workington                                 0.000000                1.077343
# Worksop and Retford                        0.308292                1.061589
# Worthing                                   1.929442                0.993752
# Wrexham                                    0.520850                1.057953
# Yeovil                                     1.028792                1.038553
# York                                       0.771989                1.026909
#
# [231 rows x 29 columns]

# %%
fig,ax = plt.subplots(figsize=(10,10))

lq_correlations = combined_lq_df.corr()

lq_correlations.columns = [x.lower() for x in lq_correlations.columns]
lq_correlations.index = [x.lower() for x in lq_correlations.index]

ax.imshow(lq_correlations.loc[sorted(lq_correlations.columns),
                              sorted(lq_correlations.columns)],cmap='seismic')

ax.set_xticks(np.arange(0,len(lq_correlations)))
ax.set_xticklabels(sorted(lq_correlations.columns),rotation=90)

ax.set_yticks(np.arange(0,len(lq_correlations)))
ax.set_yticklabels(sorted(lq_correlations.columns))
# Out:
# [Text(0,0,'advertising_marketing_glai_embedded'),
#  Text(0,0,'advertising_marketing_glai_spec'),
#  Text(0,0,'advertising_marketing_official'),
#  Text(0,0,'architecture_glai_embedded'),
#  Text(0,0,'architecture_glai_spec'),
#  Text(0,0,'architecture_official'),
#  Text(0,0,'crafts_glai_embedded'),
#  Text(0,0,'crafts_glai_spec'),
#  Text(0,0,'crafts_official'),
#  Text(0,0,'design_glai_embedded'),
#  Text(0,0,'design_glai_spec'),
#  Text(0,0,'design_official'),
#  Text(0,0,'it_software_glai_embedded'),
#  Text(0,0,'it_software_glai_spec'),
#  Text(0,0,'it_software_official'),
#  Text(0,0,'libraries_museums_glai_embedded'),
#  Text(0,0,'libraries_museums_glai_spec'),
#  Text(0,0,'libraries_museums_official'),
#  Text(0,0,'music_performing_arts_glai_embedded'),
#  Text(0,0,'music_performing_arts_glai_spec'),
#  Text(0,0,'music_performing_arts_official'),
#  Text(0,0,'non_creative'),
#  Text(0,0,'not_in_sector_official'),
#  Text(0,0,'publishing_glai_embedded'),
#  Text(0,0,'publishing_glai_spec'),
#  Text(0,0,'publishing_official'),
#  Text(0,0,'video_film_photography_glai_embedded'),
#  Text(0,0,'video_film_photography_glai_spec'),
#  Text(0,0,'video_film_photography_official')]

# %%
out = extract_examples(creative='video_film_photography',non_creative='Industrial and Agriculture',place='Bath')

# %%
#pd.Series(
#    [x for el in glai_labelled.loc[glai_labelled.ttwa_name=='Cardiff','long_topics'] for x in el]).value_counts()
# Out:
# south wales                 12
# long term                    9
# high quality                 9
# web design                   6
# social media                 6
# news item                    5
# web technology               5
# service value                5
# exceeds expectations         5
# sports industry              5
# content creation             4
# young person                 4
# client base                  4
# search engine                4
# business intelligence        4
# large scale                  4
# interior design              4
# welsh business               4
# online presence              4
# key communication            4
# public relation              4
# dedicated content            4
# creative design              4
# customer service             4
# welsh language               4
# bespoke jewellery            4
# team member                  3
# architectural practice       3
# high end                     3
# web development              3
#                             ..
# government organisations     1
# mission success              1
# significant savings          1
# international client         1
# independent campaign         1
# outline planning             1
# civil engineering            1
# principal technology         1
# construction jobs            1
# retirement village           1
# clear communication          1
# shelf software               1
# business risks               1
# regeneration project         1
# power point presentation     1
# software distribution        1
# previous years               1
# career development           1
# free account                 1
# sales managers               1
# service automation           1
# cyber essentials             1
# intelligent design           1
# authentication systems       1
# new labour                   1
# fire safety                  1
# crime commissioner           1
# retail energy                1
# interview series             1
# numerous challenges          1
# Length: 3132, dtype: int64

# %%
 glai_labelled.columns
# Out:
# Index(['index', 'name', 'creative_glai_sector', 'creative_glai_subsector',
#        'source', 'source_glai_sector', 'source_glai_subsector',
#        'sector_probabilities', 'website', 'topics_list', 'description_1',
#        'description2', 'long_topics', 'postcode_list', 'postcode_top', 'pcds',
#        'laua', 'gor', 'ttwa', 'ttwa_code', 'ttwa_name', 'sector', 'subsector',
#        'dcms_sector', 'has_top_subsector'],
#       dtype='object')
